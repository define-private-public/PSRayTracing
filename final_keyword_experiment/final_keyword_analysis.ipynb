# %% [markdown]
# Please note that I'm mostly a C++ dev; I'm not the best with Python and data
# analysis, so this code is a bit more sloppy that I'd like it to be.  My apologies.
#
# Also, due to a bug, the scene `book1::glass_blue_metal_spheres` was doubly tested.
# I don't think it makes sense to prune one of the runs from the testing data.  When
# analyzing it, nothing looks to be out of the ordinary or swaying the results in one
# direction over the other.  If anything it actually gives more more data to inspect
# and average later on.  It's the rare time where a bug actually became a feature!
# (I will be fixing it and updating the test cases later on in the nearish future)

# %%
from openpyxl import load_workbook
from dataclasses import dataclass
import pandas as pd
import numpy as np
import matplotlib as plt
from pprint import pprint

num_test_cases = 1170   # TODO, it would be nice to somehow grab this value from the spreadsheet and not hard code it...
sheet_file_name ='final_keyword_test_suite_results.xlsx'
excel_file = load_workbook(sheet_file_name)

# %%
from dataclasses import dataclass

@dataclass
class TestCase:
    id_num: int
    scene_id: str

    # runtimes, measured in nanoseconds
    without_final_runtime_ns: int
    with_final_runtime_ns: int

    def was_final_faster(self) -> bool:
        '''Checks if use of final was faster for this'''
        return (self.with_final_runtime_ns < self.without_final_runtime_ns)

    def final_slower_by_ns(self) -> int:
        '''How much slower using `final` was. Could return a negative, meaning final was faster'''
        return self.with_final_runtime_ns - self.without_final_runtime_ns

    def final_faster_by_ns(self) -> int:
        '''How much final was faser by, may return a negative meaning it was slower'''
        return -self.final_slower_by_ns()

    def percent_final_slower_by(self) -> float:
        '''Percent-wise how much slower final was'''
        return (self.with_final_runtime_ns - self.without_final_runtime_ns) / self.without_final_runtime_ns

    def percent_final_faster_by(self) -> float:
        '''Percent-wise how much faster final was'''
        return (self.without_final_runtime_ns - self.with_final_runtime_ns) / self.without_final_runtime_ns

# %%
def _ns_to_time_str(nanoseconds: int) -> str:
    total_seconds = nanoseconds // 1000000000
    hours = total_seconds // (60 * 60)
    s = total_seconds % (60 * 60)
    minutes = s // 60
    seconds = s % 60
    
    return f'{hours}h {minutes}m {seconds}s'
    

@dataclass
class TestSuite:
    cpu: str
    os: str
    compiler: str

    # Measured in nanoseconds
    without_final_total_runtime_ns: int
    with_final_total_runtime_ns: int

    test_cases: list[TestCase]

    def without_final_total_runtime_str(self) -> str:
        return _ns_to_time_str(self.without_final_total_runtime_ns)
        
    def with_final_total_runtime_str(self) -> str:
        return _ns_to_time_str(self.with_final_total_runtime_ns)

    def pandas_column_header(self) -> str:
        '''For displaying the configuration in a header in a table'''
        return '<br>'.join([self.compiler, self.cpu, self.os])

    def overall_was_final_more_performant(self) -> bool:
        return (self.with_final_total_runtime_ns < self.without_final_total_runtime_ns)

    def overall_how_much_faster_was_final(self) -> float:
        # Assumes that final was always faster
        diff = self.without_final_total_runtime_ns - self.with_final_total_runtime_ns
        return (diff / self.without_final_total_runtime_ns)

    def _find_cases_where(self, comparison_func) -> list[TestCase]:
        '''Internal function to compare the final vs. non-used-final test case,
        and collect them into a list.  comparision_func takes one arguement (a test
        case) and should return a bool'''
        return list(filter(lambda x: comparison_func(x), self.test_cases))
        
    def find_cases_where_final_was_slower(self) -> list[TestCase]:
        '''Retuns a list of test cases where the usage of `final` was slower'''
        def _final_slower(test_case):
            return (test_case.with_final_runtime_ns >= test_case.without_final_runtime_ns)

        return self._find_cases_where(_final_slower)

    def find_cases_where_final_was_faster(self) -> list[TestCase]:
        '''Returns a list of test cases where the usage of `final` was faster'''
        def _final_faster(test_case):
            return (test_case.with_final_runtime_ns < test_case.without_final_runtime_ns)

        return self._find_cases_where(_final_faster)        

    def find_cases_where_final_was_slower_by_at_least(self, by_percent: float) -> list[TestCase]:
        '''Find where the test case was slower with `final` turned on;  By a certain percentage'''
        all_where_slower = self.find_cases_where_final_was_slower()
        return list(filter(lambda x: (x.percent_final_slower_by() >= by_percent), all_where_slower))
        
    def find_cases_where_final_was_faster_by_at_least(self, by_percent: float) -> list[TestCase]:
        '''Find where the test case was faster with `final` turned on;  By a certain percentage'''
        all_where_faster = self.find_cases_where_final_was_faster()
        return list(filter(lambda x: (x.percent_final_faster_by() >= by_percent), all_where_faster))

    def find_cases_that_took_at_least(self, how_many_seconds: float) -> list[TestCase]:
        '''Tries to find the test cases where with/without final it took a few seconds'''
        def _at_least_n_seconds(test_case):
            final_runtime_s = test_case.with_final_runtime_ns / 1000000000
            without_final_runtime_s = test_case.without_final_runtime_ns / 1000000000
            return ((final_runtime_s > how_many_seconds) or (without_final_runtime_s > how_many_seconds))

        return self._find_cases_where(_at_least_n_seconds)

# %%
results = []
num_configurations = 0

def pairwise(iterable):
    a = iter(iterable)
    return zip(a, a)

# Parse the data into something we can use/analyze
for (without_final, with_final) in pairwise(excel_file.worksheets):
    num_configurations += 1
    
    # Extract out the summary data
    without_final_summary_data = without_final['A1:B5']
    with_final_summary_data = with_final['A1:B5']

    # Grab the configuration (and results of each individual test)
    data_start_offset = 8
    range_to_grab = f'A{data_start_offset}:I{data_start_offset + num_test_cases - 1}'
    without_final_test_data = without_final[range_to_grab]
    with_final_test_data = with_final[range_to_grab]
    
    # Get all the data from each test case
    test_cases = []
    for r in range(0, num_test_cases):
        test_cases.append(TestCase(
            int(without_final_test_data[r][0].value),      # id no.
            without_final_test_data[r][1].value,           # scene name

            # Render time
            int(without_final_test_data[r][8].value),
            int(with_final_test_data[r][8].value)
        ))

    # Put them into the suite results
    results.append(TestSuite(
        without_final_summary_data[0][1].value,
        without_final_summary_data[1][1].value,
        without_final_summary_data[2][1].value,
        
        int(without_final_summary_data[4][1].value),
        int(with_final_summary_data[4][1].value),
        test_cases
    ))

# %%
# Make a chart showing the overall performance
configs = [x.pandas_column_header() for x in results]
data = [
    [('Yes' if x.overall_was_final_more_performant() else 'No') for x in results],
    [('{:.2%}'.format(x.overall_how_much_faster_was_final())) for x in results],
    [x.without_final_total_runtime_str() for x in results],
    [x.with_final_total_runtime_str() for x in results],
]
row_labels = [
    'Was <code>final</code> faster?',
    'By how much',
    'Total run time without <code>final</final>',
    'Total run time with <code>final</final>',
]
overall_table = pd.DataFrame(columns=configs, data=data)
overall_table.style\
  .set_caption(f'<h1>Overall Performance</h1>')\
  .relabel_index(row_labels, axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0cc92">
#   <caption><h1>Overall Performance</h1></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cc92_level0_col0" class="col_heading level0 col0" >GCC 13.2.0<br>AMD Ryzen 9 6900HX<br>Ubuntu 23.10</th>
#       <th id="T_0cc92_level0_col1" class="col_heading level0 col1" >Clang 17.0.2<br>AMD Ryzen 9 6900HX<br>Ubuntu 23.10</th>
#       <th id="T_0cc92_level0_col2" class="col_heading level0 col2" >MSVC 17<br>AMD Ryzen 9 6900HX<br>Windows 11 Home (22631.3085)</th>
#       <th id="T_0cc92_level0_col3" class="col_heading level0 col3" >GCC 13.2.0 (w64devkit)<br>AMD Ryzen 9 6900HX<br>Windows 11 Home (22631.3085)</th>
#       <th id="T_0cc92_level0_col4" class="col_heading level0 col4" >Clang 15<br>M1<br>macOS 14.3 (23D56)</th>
#       <th id="T_0cc92_level0_col5" class="col_heading level0 col5" >GCC 13.2.0 (homebrew)<br>M1<br>macOS 14.3 (23D56)</th>
#       <th id="T_0cc92_level0_col6" class="col_heading level0 col6" >GCC 12.3.0<br>i7-10750H<br>Ubuntu 22.04.3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cc92_level0_row0" class="row_heading level0 row0" >Was <code>final</code> faster?</th>
#       <td id="T_0cc92_row0_col0" class="data row0 col0" >Yes</td>
#       <td id="T_0cc92_row0_col1" class="data row0 col1" >No</td>
#       <td id="T_0cc92_row0_col2" class="data row0 col2" >No</td>
#       <td id="T_0cc92_row0_col3" class="data row0 col3" >Yes</td>
#       <td id="T_0cc92_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_0cc92_row0_col5" class="data row0 col5" >Yes</td>
#       <td id="T_0cc92_row0_col6" class="data row0 col6" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_0cc92_level0_row1" class="row_heading level0 row1" >By how much</th>
#       <td id="T_0cc92_row1_col0" class="data row1 col0" >3.62%</td>
#       <td id="T_0cc92_row1_col1" class="data row1 col1" >-9.91%</td>
#       <td id="T_0cc92_row1_col2" class="data row1 col2" >-3.66%</td>
#       <td id="T_0cc92_row1_col3" class="data row1 col3" >3.57%</td>
#       <td id="T_0cc92_row1_col4" class="data row1 col4" >0.05%</td>
#       <td id="T_0cc92_row1_col5" class="data row1 col5" >1.94%</td>
#       <td id="T_0cc92_row1_col6" class="data row1 col6" >0.44%</td>
#     </tr>
#     <tr>
#       <th id="T_0cc92_level0_row2" class="row_heading level0 row2" >Total run time without <code>final</final></th>
#       <td id="T_0cc92_row2_col0" class="data row2 col0" >8h 8m 11s</td>
#       <td id="T_0cc92_row2_col1" class="data row2 col1" >12h 19m 49s</td>
#       <td id="T_0cc92_row2_col2" class="data row2 col2" >11h 48m 53s</td>
#       <td id="T_0cc92_row2_col3" class="data row2 col3" >10h 22m 54s</td>
#       <td id="T_0cc92_row2_col4" class="data row2 col4" >5h 21m 22s</td>
#       <td id="T_0cc92_row2_col5" class="data row2 col5" >5h 38m 50s</td>
#       <td id="T_0cc92_row2_col6" class="data row2 col6" >8h 46m 59s</td>
#     </tr>
#     <tr>
#       <th id="T_0cc92_level0_row3" class="row_heading level0 row3" >Total run time with <code>final</final></th>
#       <td id="T_0cc92_row3_col0" class="data row3 col0" >7h 50m 30s</td>
#       <td id="T_0cc92_row3_col1" class="data row3 col1" >13h 33m 10s</td>
#       <td id="T_0cc92_row3_col2" class="data row3 col2" >12h 14m 48s</td>
#       <td id="T_0cc92_row3_col3" class="data row3 col3" >10h 0m 40s</td>
#       <td id="T_0cc92_row3_col4" class="data row3 col4" >5h 21m 12s</td>
#       <td id="T_0cc92_row3_col5" class="data row3 col5" >5h 32m 17s</td>
#       <td id="T_0cc92_row3_col6" class="data row3 col6" >8h 44m 39s</td>
#     </tr>
#   </tbody>
# </table>

# %%
def make_table_showing_performance_percentages(slower_or_faster: str, lower: int = 1, upper: int = 5):
    '''This function will generate a table that will show for each configuration, how
    many tests (percentage) wise are faster or slower with `final` on or off.  It's
    a little confusing TBH.  First arugument to this function should be `slower` or `faster`;
    the second and third arguments are the range to show (inclusive).'''

    # Decide on the colour, and function to use to grab tests
    if slower_or_faster == 'slower':
        cmap = 'YlOrRd'
        f = TestSuite.find_cases_where_final_was_slower_by_at_least
    elif slower_or_faster == 'faster':
        cmap = 'Greens'
        f = TestSuite.find_cases_where_final_was_faster_by_at_least

    # Percentages to test
    perf_percentages = [(x / 100) for x in range(lower, (upper + 1))]
    
    row_labels = []
    data = []
    for pp in perf_percentages:
        row_labels.append(f'≥ {pp:.0%} {slower_or_faster}')
        row_data = []

        # Figure out the percentage of test cases, at or above the performance level
        for r in results:
            cases = f(r, pp)
            ratio = len(cases) / num_test_cases
            row_data.append(ratio)
    
        data.append(row_data)
    
    def _make_pretty(styler):
        styler.set_caption(f'<h2>Percent of test cases that are {slower_or_faster} with <code>final</code> turned on</h2><h4>(out of {num_test_cases} test cases)</h4><br><br>')
        styler.relabel_index(row_labels, axis=0)
        styler.format('{:.1%}')
        styler.background_gradient(axis=None, cmap=cmap, vmin=0, vmax=1)
        return styler
    
    # Display the data
    table = pd.DataFrame(columns=configs, data=data)
    return (table, _make_pretty)

# %%
# Show the faster cases
(table, make_pretty) = make_table_showing_performance_percentages('faster', 1, 10)
table.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_db4ae_row0_col0 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_db4ae_row0_col1, #T_db4ae_row7_col3 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_db4ae_row0_col2 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_db4ae_row0_col3 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_db4ae_row0_col4 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_db4ae_row0_col5, #T_db4ae_row1_col6 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_db4ae_row0_col6 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_db4ae_row1_col0 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_db4ae_row1_col1, #T_db4ae_row6_col5, #T_db4ae_row8_col3 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_db4ae_row1_col2 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_db4ae_row1_col3 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_db4ae_row1_col4, #T_db4ae_row4_col5 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_db4ae_row1_col5, #T_db4ae_row4_col3, #T_db4ae_row5_col0 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_db4ae_row2_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_db4ae_row2_col1, #T_db4ae_row9_col3 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_db4ae_row2_col2 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_db4ae_row2_col3 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_db4ae_row2_col4, #T_db4ae_row3_col1, #T_db4ae_row4_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_db4ae_row2_col5 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_db4ae_row2_col6, #T_db4ae_row4_col0 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_db4ae_row3_col0 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_db4ae_row3_col2 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_db4ae_row3_col3 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_db4ae_row3_col4, #T_db4ae_row4_col4, #T_db4ae_row7_col1, #T_db4ae_row8_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_db4ae_row3_col5, #T_db4ae_row7_col0 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_db4ae_row3_col6, #T_db4ae_row4_col2 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_db4ae_row4_col6 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_db4ae_row5_col1, #T_db4ae_row6_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_db4ae_row5_col2 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_db4ae_row5_col3 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_db4ae_row5_col4, #T_db4ae_row7_col5, #T_db4ae_row9_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_db4ae_row5_col5, #T_db4ae_row9_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_db4ae_row5_col6 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_db4ae_row6_col0, #T_db4ae_row9_col2 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_db4ae_row6_col2, #T_db4ae_row6_col6 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_db4ae_row6_col3, #T_db4ae_row8_col0 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_db4ae_row6_col4, #T_db4ae_row7_col4, #T_db4ae_row8_col4, #T_db4ae_row8_col5, #T_db4ae_row9_col4, #T_db4ae_row9_col5 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_db4ae_row7_col2, #T_db4ae_row7_col6 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_db4ae_row8_col2, #T_db4ae_row8_col6, #T_db4ae_row9_col6 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# </style>
# <table id="T_db4ae">
#   <caption><h2>Percent of test cases that are faster with <code>final</code> turned on</h2><h4>(out of 1170 test cases)</h4><br><br></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db4ae_level0_col0" class="col_heading level0 col0" >GCC 13.2.0<br>AMD Ryzen 9 6900HX<br>Ubuntu 23.10</th>
#       <th id="T_db4ae_level0_col1" class="col_heading level0 col1" >Clang 17.0.2<br>AMD Ryzen 9 6900HX<br>Ubuntu 23.10</th>
#       <th id="T_db4ae_level0_col2" class="col_heading level0 col2" >MSVC 17<br>AMD Ryzen 9 6900HX<br>Windows 11 Home (22631.3085)</th>
#       <th id="T_db4ae_level0_col3" class="col_heading level0 col3" >GCC 13.2.0 (w64devkit)<br>AMD Ryzen 9 6900HX<br>Windows 11 Home (22631.3085)</th>
#       <th id="T_db4ae_level0_col4" class="col_heading level0 col4" >Clang 15<br>M1<br>macOS 14.3 (23D56)</th>
#       <th id="T_db4ae_level0_col5" class="col_heading level0 col5" >GCC 13.2.0 (homebrew)<br>M1<br>macOS 14.3 (23D56)</th>
#       <th id="T_db4ae_level0_col6" class="col_heading level0 col6" >GCC 12.3.0<br>i7-10750H<br>Ubuntu 22.04.3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db4ae_level0_row0" class="row_heading level0 row0" >≥ 1% faster</th>
#       <td id="T_db4ae_row0_col0" class="data row0 col0" >66.3%</td>
#       <td id="T_db4ae_row0_col1" class="data row0 col1" >3.8%</td>
#       <td id="T_db4ae_row0_col2" class="data row0 col2" >32.4%</td>
#       <td id="T_db4ae_row0_col3" class="data row0 col3" >35.4%</td>
#       <td id="T_db4ae_row0_col4" class="data row0 col4" >14.5%</td>
#       <td id="T_db4ae_row0_col5" class="data row0 col5" >22.7%</td>
#       <td id="T_db4ae_row0_col6" class="data row0 col6" >29.7%</td>
#     </tr>
#     <tr>
#       <th id="T_db4ae_level0_row1" class="row_heading level0 row1" >≥ 2% faster</th>
#       <td id="T_db4ae_row1_col0" class="data row1 col0" >49.0%</td>
#       <td id="T_db4ae_row1_col1" class="data row1 col1" >3.5%</td>
#       <td id="T_db4ae_row1_col2" class="data row1 col2" >25.5%</td>
#       <td id="T_db4ae_row1_col3" class="data row1 col3" >25.2%</td>
#       <td id="T_db4ae_row1_col4" class="data row1 col4" >5.4%</td>
#       <td id="T_db4ae_row1_col5" class="data row1 col5" >10.6%</td>
#       <td id="T_db4ae_row1_col6" class="data row1 col6" >23.0%</td>
#     </tr>
#     <tr>
#       <th id="T_db4ae_level0_row2" class="row_heading level0 row2" >≥ 3% faster</th>
#       <td id="T_db4ae_row2_col0" class="data row2 col0" >36.0%</td>
#       <td id="T_db4ae_row2_col1" class="data row2 col1" >2.9%</td>
#       <td id="T_db4ae_row2_col2" class="data row2 col2" >19.9%</td>
#       <td id="T_db4ae_row2_col3" class="data row2 col3" >18.2%</td>
#       <td id="T_db4ae_row2_col4" class="data row2 col4" >2.6%</td>
#       <td id="T_db4ae_row2_col5" class="data row2 col5" >6.5%</td>
#       <td id="T_db4ae_row2_col6" class="data row2 col6" >15.7%</td>
#     </tr>
#     <tr>
#       <th id="T_db4ae_level0_row3" class="row_heading level0 row3" >≥ 4% faster</th>
#       <td id="T_db4ae_row3_col0" class="data row3 col0" >22.1%</td>
#       <td id="T_db4ae_row3_col1" class="data row3 col1" >2.6%</td>
#       <td id="T_db4ae_row3_col2" class="data row3 col2" >16.4%</td>
#       <td id="T_db4ae_row3_col3" class="data row3 col3" >14.0%</td>
#       <td id="T_db4ae_row3_col4" class="data row3 col4" >1.8%</td>
#       <td id="T_db4ae_row3_col5" class="data row3 col5" >5.5%</td>
#       <td id="T_db4ae_row3_col6" class="data row3 col6" >13.6%</td>
#     </tr>
#     <tr>
#       <th id="T_db4ae_level0_row4" class="row_heading level0 row4" >≥ 5% faster</th>
#       <td id="T_db4ae_row4_col0" class="data row4 col0" >15.8%</td>
#       <td id="T_db4ae_row4_col1" class="data row4 col1" >2.5%</td>
#       <td id="T_db4ae_row4_col2" class="data row4 col2" >13.3%</td>
#       <td id="T_db4ae_row4_col3" class="data row4 col3" >10.6%</td>
#       <td id="T_db4ae_row4_col4" class="data row4 col4" >1.6%</td>
#       <td id="T_db4ae_row4_col5" class="data row4 col5" >5.4%</td>
#       <td id="T_db4ae_row4_col6" class="data row4 col6" >12.2%</td>
#     </tr>
#     <tr>
#       <th id="T_db4ae_level0_row5" class="row_heading level0 row5" >≥ 6% faster</th>
#       <td id="T_db4ae_row5_col0" class="data row5 col0" >10.6%</td>
#       <td id="T_db4ae_row5_col1" class="data row5 col1" >2.3%</td>
#       <td id="T_db4ae_row5_col2" class="data row5 col2" >11.8%</td>
#       <td id="T_db4ae_row5_col3" class="data row5 col3" >7.5%</td>
#       <td id="T_db4ae_row5_col4" class="data row5 col4" >1.2%</td>
#       <td id="T_db4ae_row5_col5" class="data row5 col5" >4.5%</td>
#       <td id="T_db4ae_row5_col6" class="data row5 col6" >11.0%</td>
#     </tr>
#     <tr>
#       <

# %%
# Show the slower cases
(table, make_pretty) = make_table_showing_performance_percentages('slower', 1, 10)
table.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_392fd_row0_col0 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_392fd_row0_col1 {
#   background-color: #9b0026;
#   color: #f1f1f1;
# }
# #T_392fd_row0_col2 {
#   background-color: #fd9e43;
#   color: #000000;
# }
# #T_392fd_row0_col3 {
#   background-color: #feca66;
#   color: #000000;
# }
# #T_392fd_row0_col4 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_392fd_row0_col5 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_392fd_row0_col6 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_392fd_row1_col0, #T_392fd_row5_col3 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_392fd_row1_col1 {
#   background-color: #a20026;
#   color: #f1f1f1;
# }
# #T_392fd_row1_col2 {
#   background-color: #feae4a;
#   color: #000000;
# }
# #T_392fd_row1_col3 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_392fd_row1_col4, #T_392fd_row6_col3 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_392fd_row1_col5 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_392fd_row1_col6 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_392fd_row2_col0 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_392fd_row2_col1 {
#   background-color: #aa0026;
#   color: #f1f1f1;
# }
# #T_392fd_row2_col2 {
#   background-color: #feba55;
#   color: #000000;
# }
# #T_392fd_row2_col3, #T_392fd_row3_col6 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_392fd_row2_col4 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_392fd_row2_col5 {
#   background-color: #fffac0;
#   color: #000000;
# }
# #T_392fd_row2_col6 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_392fd_row3_col0, #T_392fd_row3_col4 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_392fd_row3_col1 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_392fd_row3_col2 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_392fd_row3_col3, #T_392fd_row6_col6 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_392fd_row3_col5 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_392fd_row4_col0 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_392fd_row4_col1 {
#   background-color: #b60026;
#   color: #f1f1f1;
# }
# #T_392fd_row4_col2 {
#   background-color: #fed572;
#   color: #000000;
# }
# #T_392fd_row4_col3 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_392fd_row4_col4, #T_392fd_row4_col5, #T_392fd_row5_col0, #T_392fd_row5_col4, #T_392fd_row5_col5, #T_392fd_row6_col5 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_392fd_row4_col6 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_392fd_row5_col1 {
#   background-color: #bb0026;
#   color: #f1f1f1;
# }
# #T_392fd_row5_col2 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_392fd_row5_col6 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_392fd_row6_col0, #T_392fd_row6_col4, #T_392fd_row7_col0, #T_392fd_row7_col4, #T_392fd_row7_col5, #T_392fd_row8_col0, #T_392fd_row8_col4, #T_392fd_row8_col5, #T_392fd_row9_col0, #T_392fd_row9_col4, #T_392fd_row9_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_392fd_row6_col1 {
#   background-color: #c40524;
#   color: #f1f1f1;
# }
# #T_392fd_row6_col2 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_392fd_row7_col1 {
#   background-color: #cb0a22;
#   color: #f1f1f1;
# }
# #T_392fd_row7_col2 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_392fd_row7_col3 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_392fd_row7_col6 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_392fd_row8_col1 {
#   background-color: #d30f20;
#   color: #f1f1f1;
# }
# #T_392fd_row8_col2 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_392fd_row8_col3 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_392fd_row8_col6 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_392fd_row9_col1 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_392fd_row9_col2 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_392fd_row9_col3 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_392fd_row9_col6 {
#   background-color: #fff3af;
#   color: #000000;
# }
# </style>
# <table id="T_392fd">
#   <caption><h2>Percent of test cases that are slower with <code>final</code> turned on</h2><h4>(out of 1170 test cases)</h4><br><br></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_392fd_level0_col0" class="col_heading level0 col0" >GCC 13.2.0<br>AMD Ryzen 9 6900HX<br>Ubuntu 23.10</th>
#       <th id="T_392fd_level0_col1" class="col_heading level0 col1" >Clang 17.0.2<br>AMD Ryzen 9 6900HX<br>Ubuntu 23.10</th>
#       <th id="T_392fd_level0_col2" class="col_heading level0 col2" >MSVC 17<br>AMD Ryzen 9 6900HX<br>Windows 11 Home (22631.3085)</th>
#       <th id="T_392fd_level0_col3" class="col_heading level0 col3" >GCC 13.2.0 (w64devkit)<br>AMD Ryzen 9 6900HX<br>Windows 11 Home (22631.3085)</th>
#       <th id="T_392fd_level0_col4" class="col_heading level0 col4" >Clang 15<br>M1<br>macOS 14.3 (23D56)</th>
#       <th id="T_392fd_level0_col5" class="col_heading level0 col5" >GCC 13.2.0 (homebrew)<br>M1<br>macOS 14.3 (23D56)</th>
#       <th id="T_392fd_level0_col6" class="col_heading level0 col6" >GCC 12.3.0<br>i7-10750H<br>Ubuntu 22.04.3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_392fd_level0_row0" class="row_heading level0 row0" >≥ 1% slower</th>
#       <td id="T_392fd_row0_col0" class="data row0 col0" >11.3%</td>
#       <td id="T_392fd_row0_col1" class="data row0 col1" >94.3%</td>
#       <td id="T_392fd_row0_col2" class="data row0 col2" >44.4%</td>
#       <td id="T_392fd_row0_col3" class="data row0 col3" >29.9%</td>
#       <td id="T_392fd_row0_col4" class="data row0 col4" >12.3%</td>
#       <td id="T_392fd_row0_col5" class="data row0 col5" >11.5%</td>
#       <td id="T_392fd_row0_col6" class="data row0 col6" >25.4%</td>
#     </tr>
#     <tr>
#       <th id="T_392fd_level0_row1" class="row_heading level0 row1" >≥ 2% slower</th>
#       <td id="T_392fd_row1_col0" class="data row1 col0" >6.5%</td>
#       <td id="T_392fd_row1_col1" class="data row1 col1" >92.9%</td>
#       <td id="T_392fd_row1_col2" class="data row1 col2" >39.1%</td>
#       <td id="T_392fd_row1_col3" class="data row1 col3" >18.8%</td>
#       <td id="T_392fd_row1_col4" class="data row1 col4" >5.1%</td>
#       <td id="T_392fd_row1_col5" class="data row1 col5" >5.8%</td>
#       <td id="T_392fd_row1_col6" class="data row1 col6" >19.6%</td>
#     </tr>
#     <tr>
#       <th id="T_392fd_level0_row2" class="row_heading level0 row2" >≥ 3% slower</th>
#       <td id="T_392fd_row2_col0" class="data row2 col0" >3.2%</td>
#       <td id="T_392fd_row2_col1" class="data row2 col1" >91.2%</td>
#       <td id="T_392fd_row2_col2" class="data row2 col2" >35.0%</td>
#       <td id="T_392fd_row2_col3" class="data row2 col3" >12.7%</td>
#       <td id="T_392fd_row2_col4" class="data row2 col4" >2.5%</td>
#       <td id="T_392fd_row2_col5" class="data row2 col5" >3.6%</td>
#       <td id="T_392fd_row2_col6" class="data row2 col6" >15.1%</td>
#     </tr>
#     <tr>
#       <th id="T_392fd_level0_row3" class="row_heading level0 row3" >≥ 4% slower</th>
#       <td id="T_392fd_row3_col0" class="data row3 col0" >1.5%</td>
#       <td id="T_392fd_row3_col1" class="data row3 col1" >90.2%</td>
#       <td id="T_392fd_row3_col2" class="data row3 col2" >30.4%</td>
#       <td id="T_392fd_row3_col3" class="data row3 col3" >9.5%</td>
#       <td id="T_392fd_row3_col4" class="data row3 col4" >1.2%</td>
#       <td id="T_392fd_row3_col5" class="data row3 col5" >1.9%</td>
#       <td id="T_392fd_row3_col6" class="data row3 col6" >12.6%</td>
#     </tr>
#     <tr>
#       <th id="T_392fd_level0_row4" class="row_heading level0 row4" >≥ 5% slower</th>
#       <td id="T_392fd_row4_col0" class="data row4 col0" >0.9%</td>
#       <td id="T_392fd_row4_col1" class="data row4 col1" >89.1%</td>
#       <td id="T_392fd_row4_col2" class="data row4 col2" >26.2%</td>
#       <td id="T_392fd_row4_col3" class="data row4 col3" >7.1%</td>
#       <td id="T_392fd_row4_col4" class="data row4 col4" >0.7%</td>
#       <td id="T_392fd_row4_col5" class="data row4 col5" >0.8%</td>
#       <td id="T_392fd_row4_col6" class="data row4 col6" >10.6%</td>
#     </tr>
#     <tr>
#       <th id="T_392fd_level0_row5"

# %%
# Collapse each iterate of each scene to show averages to see if it was more performant or not
from statistics import mean, median, stdev, variance
from collections import OrderedDict

# Not a fan of doing this, but it extracts the scene Id's for us to display in the table
_scene_ids = []

def compute_stats_per_config(config_index: int):
    global _scene_ids
    
    suite = results[config_index]
    all_scenes = OrderedDict()
    
    # Organize each scene to see how much percent faster it is
    for tc in suite.test_cases:
        sid = tc.scene_id
        p_faster = tc.percent_final_faster_by()
        
        if sid in all_scenes:
            all_scenes[sid].append(p_faster)  # Add value
        else:
            all_scenes[sid] = [p_faster]      # New list
            
    data = []
    scene_ids = []
    for (scene_id, measurements) in all_scenes.items():
        scene_ids.append(scene_id)
        # Do math
        data.append({
            f'Average_{config_index}': mean(measurements),
            f'Median_{config_index}': median(measurements),
#            f'Variance_{config_index}': variance(measurements),  # This column is left out of the final table, as it's typically low.  there are some cases where it is high
        })

    _scene_ids = scene_ids
        
    return pd.DataFrame(data=data)

# Take the averages of the performance increase/hit and put them into a super table
perf_avgs = [compute_stats_per_config(x) for x in range(0, num_configurations)]

# There is a +1 to account for a scene being doubly tested.  See my note at the
# top;  It does not effect the results in a poor manner
num_test_cases_per_scene = num_test_cases // (len(_scene_ids) + 1)

print('I was having some issue createing a Multi-Index table (from arrays)')
print('And having the table be both styled and formatted nicely.  So instead')
print('each column has a configuration number appened the end of its name.')
print('Here is hwat each number means:')
for (i, config) in enumerate(configs):
    c = config.replace('<br>', ' ')
    print(f'  {i}: {c}')

super_table = pd.concat(perf_avgs, axis=1)
super_table.style\
  .format('{:.1%}')\
  .background_gradient(axis=None, cmap='RdBu', vmin=-0.1, vmax=0.1)\
  .relabel_index(_scene_ids, axis=0)\
  .set_caption(f'<h2>How much faster/slower was each scene on average if <code>final</code> was used</h2><h4>(Each scene being tested at least {num_test_cases_per_scene} times)</h4><br><br>')
# Out:
# I was having some issue createing a Multi-Index table (from arrays)
# And having the table be both styled and formatted nicely.  So instead
# each column has a configuration number appened the end of its name.
# Here is hwat each number means:
#   0: GCC 13.2.0 AMD Ryzen 9 6900HX Ubuntu 23.10
#   1: Clang 17.0.2 AMD Ryzen 9 6900HX Ubuntu 23.10
#   2: MSVC 17 AMD Ryzen 9 6900HX Windows 11 Home (22631.3085)
#   3: GCC 13.2.0 (w64devkit) AMD Ryzen 9 6900HX Windows 11 Home (22631.3085)
#   4: Clang 15 M1 macOS 14.3 (23D56)
#   5: GCC 13.2.0 (homebrew) M1 macOS 14.3 (23D56)
#   6: GCC 12.3.0 i7-10750H Ubuntu 22.04.3
# <style type="text/css">
# #T_6328a_row0_col0, #T_6328a_row8_col5, #T_6328a_row17_col1, #T_6328a_row26_col7, #T_6328a_row34_col12 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_6328a_row0_col1, #T_6328a_row6_col0, #T_6328a_row7_col13, #T_6328a_row27_col12 {
#   background-color: #e6eff4;
#   color: #000000;
# }
# #T_6328a_row0_col2, #T_6328a_row0_col3, #T_6328a_row1_col2, #T_6328a_row1_col3, #T_6328a_row2_col2, #T_6328a_row2_col3, #T_6328a_row3_col2, #T_6328a_row3_col3, #T_6328a_row4_col2, #T_6328a_row4_col3, #T_6328a_row5_col2, #T_6328a_row5_col3, #T_6328a_row6_col2, #T_6328a_row6_col3, #T_6328a_row7_col2, #T_6328a_row7_col3, #T_6328a_row8_col2, #T_6328a_row8_col3, #T_6328a_row9_col2, #T_6328a_row9_col3, #T_6328a_row11_col4, #T_6328a_row14_col6, #T_6328a_row14_col7, #T_6328a_row15_col2, #T_6328a_row15_col3, #T_6328a_row16_col2, #T_6328a_row16_col3, #T_6328a_row17_col2, #T_6328a_row17_col3, #T_6328a_row18_col2, #T_6328a_row18_col3, #T_6328a_row19_col2, #T_6328a_row19_col3, #T_6328a_row20_col2, #T_6328a_row20_col3, #T_6328a_row21_col2, #T_6328a_row21_col3, #T_6328a_row22_col2, #T_6328a_row22_col3, #T_6328a_row23_col2, #T_6328a_row23_col3, #T_6328a_row24_col2, #T_6328a_row24_col3, #T_6328a_row25_col2, #T_6328a_row25_col3, #T_6328a_row25_col4, #T_6328a_row25_col5, #T_6328a_row26_col2, #T_6328a_row26_col3, #T_6328a_row26_col4, #T_6328a_row26_col5, #T_6328a_row27_col2, #T_6328a_row27_col3, #T_6328a_row27_col4, #T_6328a_row27_col5, #T_6328a_row29_col4, #T_6328a_row29_col5, #T_6328a_row30_col2, #T_6328a_row30_col3, #T_6328a_row31_col2, #T_6328a_row31_col3, #T_6328a_row32_col2, #T_6328a_row32_col3, #T_6328a_row32_col4, #T_6328a_row33_col2, #T_6328a_row33_col3, #T_6328a_row33_col4, #T_6328a_row33_col5, #T_6328a_row34_col2, #T_6328a_row34_col3, #T_6328a_row34_col4, #T_6328a_row34_col5, #T_6328a_row35_col2, #T_6328a_row35_col3, #T_6328a_row36_col6, #T_6328a_row36_col7, #T_6328a_row37_col4, #T_6328a_row37_col5 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_6328a_row0_col4, #T_6328a_row1_col8, #T_6328a_row5_col6, #T_6328a_row6_col12, #T_6328a_row9_col11, #T_6328a_row17_col7, #T_6328a_row18_col12, #T_6328a_row23_col12, #T_6328a_row23_col13, #T_6328a_row28_col4, #T_6328a_row29_col6 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_6328a_row0_col5, #T_6328a_row8_col11, #T_6328a_row10_col10, #T_6328a_row16_col9, #T_6328a_row16_col10, #T_6328a_row21_col5, #T_6328a_row27_col10, #T_6328a_row27_col11, #T_6328a_row28_col5 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_6328a_row0_col6, #T_6328a_row0_col8, #T_6328a_row4_col11, #T_6328a_row11_col13, #T_6328a_row12_col5, #T_6328a_row19_col9, #T_6328a_row24_col9, #T_6328a_row25_col6, #T_6328a_row28_col6, #T_6328a_row31_col8, #T_6328a_row36_col8, #T_6328a_row37_col10 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_6328a_row0_col7, #T_6328a_row3_col12, #T_6328a_row6_col1, #T_6328a_row9_col9, #T_6328a_row20_col10, #T_6328a_row20_col11, #T_6328a_row26_col12, #T_6328a_row27_col6, #T_6328a_row27_col8, #T_6328a_row27_col9, #T_6328a_row29_col11, #T_6328a_row31_col9, #T_6328a_row32_col8, #T_6328a_row32_col9, #T_6328a_row35_col6, #T_6328a_row35_col10, #T_6328a_row37_col11 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_6328a_row0_col9, #T_6328a_row1_col4, #T_6328a_row1_col9, #T_6328a_row1_col13, #T_6328a_row3_col5, #T_6328a_row5_col8, #T_6328a_row10_col11, #T_6328a_row15_col6, #T_6328a_row15_col10, #T_6328a_row15_col11, #T_6328a_row16_col11, #T_6328a_row17_col11, #T_6328a_row19_col5, #T_6328a_row19_col6, #T_6328a_row23_col11, #T_6328a_row24_col11, #T_6328a_row29_col12, #T_6328a_row29_col13, #T_6328a_row34_col9, #T_6328a_row36_col13 {
#   background-color: #f7f5f4;
#   color: #000000;
# }
# #T_6328a_row0_col10, #T_6328a_row17_col6, #T_6328a_row22_col10, #T_6328a_row23_col6, #T_6328a_row23_col7, #T_6328a_row23_col8 {
#   background-color: #f9eee7;
#   color: #000000;
# }
# #T_6328a_row0_col11, #T_6328a_row1_col5, #T_6328a_row1_col11, #T_6328a_row2_col10, #T_6328a_row3_col7, #T_6328a_row3_col11, #T_6328a_row6_col6, #T_6328a_row13_col9, #T_6328a_row18_col9, #T_6328a_row19_col13, #T_6328a_row21_col8, #T_6328a_row22_col7 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_6328a_row0_col12 {
#   background-color: #f7b596;
#   color: #000000;
# }
# #T_6328a_row0_col13, #T_6328a_row12_col12 {
#   background-color: #fbd0b9;
#   color: #000000;
# }
# #T_6328a_row1_col0, #T_6328a_row8_col12, #T_6328a_row16_col1, #T_6328a_row26_col6, #T_6328a_row33_col6 {
#   background-color: #d2e6f0;
#   color: #000000;
# }
# #T_6328a_row1_col1, #T_6328a_row25_col0, #T_6328a_row29_col1, #T_6328a_row31_col10 {
#   background-color: #e1edf3;
#   color: #000000;
# }
# #T_6328a_row1_col6, #T_6328a_row13_col3, #T_6328a_row16_col6, #T_6328a_row16_col7 {
#   background-color: #fae8de;
#   color: #000000;
# }
# #T_6328a_row1_col7 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_6328a_row1_col10, #T_6328a_row20_col4 {
#   background-color: #faeae1;
#   color: #000000;
# }
# #T_6328a_row1_col12, #T_6328a_row3_col10, #T_6328a_row6_col11, #T_6328a_row7_col10, #T_6328a_row12_col10, #T_6328a_row12_col11, #T_6328a_row13_col8, #T_6328a_row14_col10, #T_6328a_row14_col11, #T_6328a_row15_col7, #T_6328a_row20_col5, #T_6328a_row23_col5 {
#   background-color: #f9f0eb;
#   color: #000000;
# }
# #T_6328a_row2_col0, #T_6328a_row6_col9, #T_6328a_row13_col13, #T_6328a_row25_col10, #T_6328a_row35_col13 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_6328a_row2_col1, #T_6328a_row4_col1, #T_6328a_row7_col12, #T_6328a_row26_col13, #T_6328a_row35_col12, #T_6328a_row36_col4 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_6328a_row2_col4, #T_6328a_row2_col6, #T_6328a_row2_col7, #T_6328a_row2_col9, #T_6328a_row2_col11, #T_6328a_row3_col9, #T_6328a_row5_col7, #T_6328a_row5_col10, #T_6328a_row5_col11, #T_6328a_row5_col13, #T_6328a_row6_col13, #T_6328a_row8_col10, #T_6328a_row11_col9, #T_6328a_row12_col6, #T_6328a_row12_col8, #T_6328a_row14_col8, #T_6328a_row14_col9, #T_6328a_row15_col9, #T_6328a_row16_col13, #T_6328a_row17_col13, #T_6328a_row18_col11, #T_6328a_row19_col4, #T_6328a_row21_col9, #T_6328a_row21_col10, #T_6328a_row21_col13, #T_6328a_row22_col13, #T_6328a_row23_col9, #T_6328a_row23_col10, #T_6328a_row24_col13, #T_6328a_row28_col9, #T_6328a_row29_col8, #T_6328a_row29_col9, #T_6328a_row33_col12, #T_6328a_row34_col8, #T_6328a_row35_col11, #T_6328a_row37_col8 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_6328a_row2_col5, #T_6328a_row4_col5, #T_6328a_row7_col5, #T_6328a_row9_col8, #T_6328a_row22_col5, #T_6328a_row22_col6, #T_6328a_row24_col12, #T_6328a_row25_col8, #T_6328a_row27_col7, #T_6328a_row29_col10, #T_6328a_row36_col10 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_6328a_row2_col8, #T_6328a_row9_col10, #T_6328a_row16_col8, #T_6328a_row17_col8, #T_6328a_row20_col12 {
#   background-color: #f9ede5;
#   color: #000000;
# }
# #T_6328a_row2_col12, #T_6328a_row11_col3 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_6328a_row2_col13, #T_6328a_row3_col13, #T_6328a_row4_col7, #T_6328a_row4_col10, #T_6328a_row5_col9, #T_6328a_row8_col13, #T_6328a_row9_col13, #T_6328a_row10_col9, #T_6328a_row11_col12, #T_6328a_row12_col9, #T_6328a_row12_col13, #T_6328a_row15_col8, #T_6328a_row15_col13, #T_6328a_row18_col10, #T_6328a_row18_col13, #T_6328a_row20_col8, #T_6328a_row20_col9, #T_6328a_row20_col13, #T_6328a_row21_col11, #T_6328a_row26_col9, #T_6328a_row28_col8, #T_6328a_row28_col10, #T_6328a_row28_col11, #T_6328a_row34_col13, #T_6328a_row35_col7, #T_6328a_row35_col9, #T_6328a_row37_col9 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_6328a_row3_col0, #T_6328a_row11_col1, #T_6328a_row14_col1, #T_6328a_row24_col0, #T_6328a_row31_col0 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_6328a_row3_col1, #T_6328a_row10_col13, #T_6328a_row16_col0, #T_6328a_row25_col1, #T_6328a_row28_col0 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_6328a_row3_col4, #T_6328a_row4_col6, #T_6328a_row7_col8, #T_6328a_row7_col9, #T_6328a_row8_col7, #T_6328a_row14_col13, #T_6328a_row19_col8, #T_6328a_row30_col9, #T_6328a_row33
