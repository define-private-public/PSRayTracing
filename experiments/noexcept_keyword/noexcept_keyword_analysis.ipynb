# %% [markdown]
# Please note that I'm mostly a C++ dev; I'm not the best with Python and data
# analysis, so this code is a bit more sloppy that I'd like it to be.  My apologies.
#
# The term "venutre" is used to describe turning on our experiment.  In this case,
# it's using the `noexcept` keyword.
#
# I want to note that the data for AMD/Windows is a little "artificial".  I ran the
# test suite twice on that platform (both with/without `noexcept` and using MSVC &
# GCC).  I then took the best results of each test case and combined the data.  I
# did this because some of it looked a little odd to me and I wanted to give Windows
# the fairest shot possible.  I have incluced the "natural" test suite results as
# separate excel files.

# %%
from dataclasses import dataclass
import statistics
from collections import OrderedDict
from openpyxl import load_workbook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sheet_file_name ='noexcept_keyword_test_suite_results.xlsx'
excel_file = load_workbook(sheet_file_name)

# How many rows down does the actual data (we're interested in) start from?
data_start_offset = 7

num_test_cases = excel_file.worksheets[0].max_row - data_start_offset
num_test_cases_per_scene = 50  # TODO would like a "smarter" way of geting this number, not hard coding it...

# %%
@dataclass
class TestCase:
    id_num: int
    scene_id: str

    # runtimes, measured in nanoseconds
    baseline_runtime_ns: int
    venture_runtime_ns: int

    def venture_slower_by_ns(self) -> int:
        '''How much slower using the venture was. Could return a negative, meaning the venture was faster'''
        return self.venture_runtime_ns - self.baseline_runtime_ns

    def venture_faster_by_ns(self) -> int:
        '''How much was the venture faster by, may return a negative meaning it was slower'''
        return -self.venture_slower_by_ns()

    def percent_venture_slower_by(self) -> float:
        '''Percent-wise how much slower the venture was'''
        return (self.venture_runtime_ns - self.baseline_runtime_ns) / self.baseline_runtime_ns

    def percent_venture_faster_by(self) -> float:
        '''Percent-wise how much faster the venture was'''
        return (self.baseline_runtime_ns - self.venture_runtime_ns) / self.baseline_runtime_ns

# %%
def _ns_to_time_str(nanoseconds: int) -> str:
    total_seconds = nanoseconds // 1000000000
    hours = total_seconds // (60 * 60)
    s = total_seconds % (60 * 60)
    minutes = s // 60
    seconds = s % 60
    
    return f'{hours}h {minutes}m {seconds}s'
    

@dataclass
class TestSuite:
    cpu: str
    os: str
    compiler: str

    # Measured in nanoseconds
    baseline_total_runtime_ns: int
    venture_total_runtime_ns: int

    test_cases: list[TestCase]

    def baseline_total_runtime_str(self) -> str:
        return _ns_to_time_str(self.baseline_total_runtime_ns)
        
    def venture_total_runtime_str(self) -> str:
        return _ns_to_time_str(self.venture_total_runtime_ns)

    def matplotlib_config_name(self) -> str:
        '''For displaying the configuration in matplotlib renderings'''
        return '\n'.join([self.cpu, self.os, self.compiler])

    def pandas_column_header(self) -> str:
        '''For displaying the configuration in a header in a table'''
        return self.matplotlib_config_name().replace('\n', '<br>')

    def overall_was_venture_more_performant(self) -> bool:
        return (self.venture_total_runtime_ns < self.baseline_total_runtime_ns)

    def overall_how_much_faster_was_venture(self) -> float:
        # Assumes that venture was always faster
        diff = self.baseline_total_runtime_ns - self.venture_total_runtime_ns
        return (diff / self.baseline_total_runtime_ns)

    def _find_cases_where(self, comparison_func) -> list[TestCase]:
        '''Internal function to compare the venture vs. non-used-venture test case,
        and collect them into a list.  comparision_func takes one arguement (a test
        case) and should return a bool'''
        return list(filter(lambda x: comparison_func(x), self.test_cases))
        
    def find_cases_where_venture_was_slower(self) -> list[TestCase]:
        '''Retuns a list of test cases where the usage of the venture was slower'''
        def _venture_slower(test_case):
            return (test_case.venture_runtime_ns >= test_case.baseline_runtime_ns)

        return self._find_cases_where(_venture_slower)

    def find_cases_where_venture_was_faster(self) -> list[TestCase]:
        '''Returns a list of test cases where the usage of the venture was faster'''
        def _venture_faster(test_case):
            return (test_case.venture_runtime_ns < test_case.baseline_runtime_ns)

        return self._find_cases_where(_venture_faster)        

    def find_cases_where_venture_was_slower_by_at_least(self, by_percent: float) -> list[TestCase]:
        '''Find where the test case was slower with the venture turned on;  By a certain percentage'''
        all_where_slower = self.find_cases_where_venture_was_slower()
        return list(filter(lambda x: (x.percent_venture_slower_by() >= by_percent), all_where_slower))
        
    def find_cases_where_venture_was_faster_by_at_least(self, by_percent: float) -> list[TestCase]:
        '''Find where the test case was faster with the venture turned on;  By a certain percentage'''
        all_where_faster = self.find_cases_where_venture_was_faster()
        return list(filter(lambda x: (x.percent_venture_faster_by() >= by_percent), all_where_faster))

# %%
results = []
num_configurations = 0

def pairwise(iterable):
    a = iter(iterable)
    return zip(a, a)

# Parse the data into something we can use/analyze
for (baseline, venture) in pairwise(excel_file.worksheets):
    num_configurations += 1
    
    # Extract out the summary data
    baseline_summary_data = baseline['A1:B5']
    venture_summary_data = venture['A1:B5']

    # Grab the configuration (and results of each individual test)
    data_start_offset = 8
    range_to_grab = f'A{data_start_offset}:I{data_start_offset + num_test_cases - 1}'
    baseline_test_data = baseline[range_to_grab]
    venture_test_data = venture[range_to_grab]
    
    # Get all the data from each test case
    test_cases = []
    for r in range(0, num_test_cases):
        test_cases.append(TestCase(
            int(baseline_test_data[r][0].value),    # id no.
            baseline_test_data[r][1].value,         # scene name

            # Render time
            int(baseline_test_data[r][8].value),
            int(venture_test_data[r][8].value)
        ))

    # Put them into the suite results
    results.append(TestSuite(
        baseline_summary_data[0][1].value,
        baseline_summary_data[1][1].value,
        baseline_summary_data[2][1].value,
        
        int(baseline_summary_data[4][1].value),
        int(venture_summary_data[4][1].value),
        test_cases
    ))

# %%
configs = [x.pandas_column_header() for x in results]

yes_str = '<div style="background-color: #BFFEBC">Yes</div>'
no_str = '<div style="background-color: #FFCFCF">No</div>'

# Make a table showing the overall performance
data = [
    [(yes_str if x.overall_was_venture_more_performant() else no_str) for x in results],
    [('{:.2%}'.format(x.overall_how_much_faster_was_venture())) for x in results],
    [x.baseline_total_runtime_str() for x in results],
    [x.venture_total_runtime_str() for x in results],
]
row_labels = [
    'Was <code>noexcept</code> faster?',
    'By how much',
    'Total run time without <code>noexcept</code>',
    'Total run time with <code>noexcept</code>',
]

overall_table = pd.DataFrame(columns=configs, data=data)
overall_table.style\
  .set_caption(f'<h1>Overall Performance</h1>')\
  .relabel_index(row_labels, axis=0)
#  .set_table_styles([{'selector': 'td', 'props': [('margin', '2em')]}])\
# Out:
# <style type="text/css">
# </style>
# <table id="T_91ccc">
#   <caption><h1>Overall Performance</h1></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91ccc_level0_col0" class="col_heading level0 col0" >Intel i7-1050H<br>Ubuntu 23.10<br>GCC 13.2.0</th>
#       <th id="T_91ccc_level0_col1" class="col_heading level0 col1" >Intel i7-1050H<br>Ubuntu 23.10<br>clang 17.0.2</th>
#       <th id="T_91ccc_level0_col2" class="col_heading level0 col2" >Intel i7-1050H<br>Windows 11 Home<br>MSVC 19.39.33523</th>
#       <th id="T_91ccc_level0_col3" class="col_heading level0 col3" >Intel i7-1050H<br>Windows 11 Home<br>GCC 14.1.0 (w64devkit)</th>
#       <th id="T_91ccc_level0_col4" class="col_heading level0 col4" >AMD Ryzen 9 6900HX<br>Ubuntu 23.10<br>GCC 13.2.0</th>
#       <th id="T_91ccc_level0_col5" class="col_heading level0 col5" >AMD Ryzen 9 6900HX<br>Ubuntu 23.10<br>clang 17.0.2</th>
#       <th id="T_91ccc_level0_col6" class="col_heading level0 col6" >AMD Ryzen 9 6900HX<br>Windows 11 Home<br>MSVC 19.38.33135</th>
#       <th id="T_91ccc_level0_col7" class="col_heading level0 col7" >AMD Ryzen 9 6900HX<br>Windows 11 Home<br>GCC 14.1.0 (w64devkit)</th>
#       <th id="T_91ccc_level0_col8" class="col_heading level0 col8" >Apple M1<br>macOS 14.4.1<br>clang 15.0.0</th>
#       <th id="T_91ccc_level0_col9" class="col_heading level0 col9" >Apple M1<br>macOS 14.4.1<br>GCC 13.2.0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91ccc_level0_row0" class="row_heading level0 row0" >Was <code>noexcept</code> faster?</th>
#       <td id="T_91ccc_row0_col0" class="data row0 col0" ><div style="background-color: #BFFEBC">Yes</div></td>
#       <td id="T_91ccc_row0_col1" class="data row0 col1" ><div style="background-color: #BFFEBC">Yes</div></td>
#       <td id="T_91ccc_row0_col2" class="data row0 col2" ><div style="background-color: #FFCFCF">No</div></td>
#       <td id="T_91ccc_row0_col3" class="data row0 col3" ><div style="background-color: #BFFEBC">Yes</div></td>
#       <td id="T_91ccc_row0_col4" class="data row0 col4" ><div style="background-color: #BFFEBC">Yes</div></td>
#       <td id="T_91ccc_row0_col5" class="data row0 col5" ><div style="background-color: #BFFEBC">Yes</div></td>
#       <td id="T_91ccc_row0_col6" class="data row0 col6" ><div style="background-color: #FFCFCF">No</div></td>
#       <td id="T_91ccc_row0_col7" class="data row0 col7" ><div style="background-color: #FFCFCF">No</div></td>
#       <td id="T_91ccc_row0_col8" class="data row0 col8" ><div style="background-color: #BFFEBC">Yes</div></td>
#       <td id="T_91ccc_row0_col9" class="data row0 col9" ><div style="background-color: #FFCFCF">No</div></td>
#     </tr>
#     <tr>
#       <th id="T_91ccc_level0_row1" class="row_heading level0 row1" >By how much</th>
#       <td id="T_91ccc_row1_col0" class="data row1 col0" >0.63%</td>
#       <td id="T_91ccc_row1_col1" class="data row1 col1" >0.54%</td>
#       <td id="T_91ccc_row1_col2" class="data row1 col2" >-2.11%</td>
#       <td id="T_91ccc_row1_col3" class="data row1 col3" >0.86%</td>
#       <td id="T_91ccc_row1_col4" class="data row1 col4" >1.08%</td>
#       <td id="T_91ccc_row1_col5" class="data row1 col5" >0.38%</td>
#       <td id="T_91ccc_row1_col6" class="data row1 col6" >-2.88%</td>
#       <td id="T_91ccc_row1_col7" class="data row1 col7" >-2.61%</td>
#       <td id="T_91ccc_row1_col8" class="data row1 col8" >0.04%</td>
#       <td id="T_91ccc_row1_col9" class="data row1 col9" >-1.50%</td>
#     </tr>
#     <tr>
#       <th id="T_91ccc_level0_row2" class="row_heading level0 row2" >Total run time without <code>noexcept</code></th>
#       <td id="T_91ccc_row2_col0" class="data row2 col0" >15h 51m 2s</td>
#       <td id="T_91ccc_row2_col1" class="data row2 col1" >21h 35m 21s</td>
#       <td id="T_91ccc_row2_col2" class="data row2 col2" >21h 17m 48s</td>
#       <td id="T_91ccc_row2_col3" class="data row2 col3" >17h 22m 1s</td>
#       <td id="T_91ccc_row2_col4" class="data row2 col4" >14h 46m 13s</td>
#       <td id="T_91ccc_row2_col5" class="data row2 col5" >21h 51m 13s</td>
#       <td id="T_91ccc_row2_col6" class="data row2 col6" >20h 11m 59s</td>
#       <td id="T_91ccc_row2_col7" class="data row2 col7" >16h 23m 25s</td>
#       <td id="T_91ccc_row2_col8" class="data row2 col8" >9h 46m 51s</td>
#       <td id="T_91ccc_row2_col9" class="data row2 col9" >10h 6m 38s</td>
#     </tr>
#     <tr>
#       <th id="T_91ccc_level0_row3" class="row_heading level0 row3" >Total run time with <code>noexcept</code></th>
#       <td id="T_91ccc_row3_col0" class="data row3 col0" >15h 45m 3s</td>
#       <td id="T_91ccc_row3_col1" class="data row3 col1" >21h 28m 23s</td>
#       <td id="T_91ccc_row3_col2" class="data row3 col2" >21h 44m 46s</td>
#       <td id="T_91ccc_row3_col3" class="data row3 col3" >17h 13m 3s</td>
#       <td id="T_91ccc_row3_col4" class="data row3 col4" >14h 36m 39s</td>
#       <td id="T_91ccc_row3_col5" class="data row3 col5" >21h 46m 12s</td>
#       <td id="T_91ccc_row3_col6" class="data row3 col6" >20h 46m 51s</td>
#       <td id="T_91ccc_row3_col7" class="data row3 col7" >16h 49m 6s</td>
#       <td id="T_91ccc_row3_col8" class="data row3 col8" >9h 46m 37s</td>
#       <td id="T_91ccc_row3_col9" class="data row3 col9" >10h 15m 44s</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Bar chart visualization of the above table

def ns_to_s(x: int) -> float:
    return x / 1000000000

def s_to_hr(x: float) -> float:
    return x / 60 / 60

def ns_to_hr(x: int) -> float:
    return s_to_hr(ns_to_s(x))

# Convert the overall suite runtime from nanoseconds to hours
baseline_runtimes = [ns_to_hr(x.baseline_total_runtime_ns) for x in results]
venture_runtimes = [ns_to_hr(x.venture_total_runtime_ns) for x in results]

configs = [x.matplotlib_config_name() for x in results]
runtimes = {
    'Baseline': baseline_runtimes,
    'With `noexcept`': venture_runtimes,
}

# Create the bar chart
x = np.arange(len(configs))
bar_width = 0.25
multiplier = 0.5

plt.rcParams['figure.figsize'] = [24, 8]
fig, ax = plt.subplots()

for (config_name, runtime_hrs) in runtimes.items():
    offset = bar_width * multiplier
    rects = ax.bar(x + offset, runtime_hrs, bar_width, label=config_name)
    ax.bar_label(rects, padding=10, fmt='%.1f')
    multiplier += 1

ax.set_title('Overall Render Times', fontsize=32, pad=50)
ax.set_ylabel('Cumulative Time (hours)', fontsize=20, labelpad=20)
ax.set_xlabel('Configuration', fontsize=20, labelpad=40)
ax.set_xticks(x + bar_width, configs)
ax.legend(loc='upper left', ncols=2)
ax.set_ylim(0, 25)

plt.show()

# %% [markdown]
# (Lower is better)
#
# ### Reminder: This is not supposed to be a compiler comparison, but a comparison of "feature-off" vs. "feature-on"

# %%
def make_table_showing_performance_percentages(slower_or_faster: str, lower: int = 1, upper: int = 5):
    '''This function will generate a table that will show for each configuration, how
    many tests (percentage) wise are faster or slower with the venture on or off.  It's
    a little confusing TBH.  First arugument to this function should be `slower` or `faster`;
    the second and third arguments are the range to show (inclusive).'''

    # Decide on the colour, and function to use to grab tests
    if slower_or_faster == 'slower':
        cmap = 'YlOrRd'
        f = TestSuite.find_cases_where_venture_was_slower_by_at_least
    elif slower_or_faster == 'faster':
        cmap = 'Greens'
        f = TestSuite.find_cases_where_venture_was_faster_by_at_least

    # Percentages to test
    perf_percentages = [(x / 100) for x in range(lower, (upper + 1))]
    
    row_labels = []
    data = []
    for pp in perf_percentages:
        row_labels.append(f'≥ {pp:.0%} {slower_or_faster}')
        row_data = []

        # Figure out the percentage of test cases, at or above the performance level
        for r in results:
            cases = f(r, pp)
            ratio = len(cases) / num_test_cases
            row_data.append(ratio)
    
        data.append(row_data)
    
    def _make_pretty(styler):
        styler.set_caption(f'<h2>Percent of test cases that are {slower_or_faster} with <code>noexcept</code> turned on</h2><h4>(out of {num_test_cases} test cases)</h4><br><br>')
        styler.relabel_index(row_labels, axis=0)
        styler.format('{:.1%}')
        styler.background_gradient(axis=None, cmap=cmap, vmin=0, vmax=1)
        return styler
    
    # Display the data
    table = pd.DataFrame(columns=configs, data=data)
    return (table, _make_pretty)

# %%
# Show the faster cases
(table, make_pretty) = make_table_showing_performance_percentages('faster', 1, 10)
table.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_95deb_row0_col0, #T_95deb_row5_col4 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_95deb_row0_col1 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_95deb_row0_col2 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_95deb_row0_col3 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_95deb_row0_col4 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_95deb_row0_col5 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_95deb_row0_col6 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_95deb_row0_col7 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_95deb_row0_col8 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_95deb_row0_col9, #T_95deb_row1_col0, #T_95deb_row2_col6 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_95deb_row1_col1 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_95deb_row1_col2, #T_95deb_row7_col4 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_95deb_row1_col3 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_95deb_row1_col4 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_95deb_row1_col5 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_95deb_row1_col6 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_95deb_row1_col7, #T_95deb_row2_col0, #T_95deb_row5_col1 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_95deb_row1_col8, #T_95deb_row3_col6, #T_95deb_row4_col0, #T_95deb_row5_col0, #T_95deb_row6_col0, #T_95deb_row7_col0 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_95deb_row1_col9, #T_95deb_row2_col2, #T_95deb_row4_col5, #T_95deb_row9_col0 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_95deb_row2_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_95deb_row2_col3 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_95deb_row2_col4 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_95deb_row2_col5 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_95deb_row2_col7, #T_95deb_row4_col6 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_95deb_row2_col8 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_95deb_row2_col9, #T_95deb_row3_col7, #T_95deb_row5_col6 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_95deb_row3_col0, #T_95deb_row8_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_95deb_row3_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_95deb_row3_col2 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_95deb_row3_col3, #T_95deb_row6_col4 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_95deb_row3_col4 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_95deb_row3_col5, #T_95deb_row6_col1, #T_95deb_row7_col1 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_95deb_row3_col8, #T_95deb_row5_col5, #T_95deb_row6_col3 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_95deb_row3_col9, #T_95deb_row6_col6, #T_95deb_row7_col3 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_95deb_row4_col1 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_95deb_row4_col2, #T_95deb_row4_col8, #T_95deb_row5_col7, #T_95deb_row7_col6 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_95deb_row4_col3, #T_95deb_row8_col4, #T_95deb_row9_col1 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_95deb_row4_col4 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_95deb_row4_col7 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_95deb_row4_col9, #T_95deb_row5_col8, #T_95deb_row6_col5, #T_95deb_row6_col7, #T_95deb_row7_col7, #T_95deb_row8_col6 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_95deb_row5_col2, #T_95deb_row5_col9, #T_95deb_row8_col3, #T_95deb_row8_col7, #T_95deb_row9_col6, #T_95deb_row9_col7 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_95deb_row5_col3, #T_95deb_row9_col4 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_95deb_row6_col2, #T_95deb_row6_col8, #T_95deb_row6_col9, #T_95deb_row7_col2, #T_95deb_row7_col5, #T_95deb_row7_col8, #T_95deb_row7_col9, #T_95deb_row8_col2, #T_95deb_row8_col5, #T_95deb_row8_col8, #T_95deb_row9_col2, #T_95deb_row9_col3, #T_95deb_row9_col8 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_95deb_row8_col0 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_95deb_row8_col9, #T_95deb_row9_col5, #T_95deb_row9_col9 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_95deb">
#   <caption><h2>Percent of test cases that are faster with <code>noexcept</code> turned on</h2><h4>(out of 1950 test cases)</h4><br><br></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95deb_level0_col0" class="col_heading level0 col0" >Intel i7-1050H
# Ubuntu 23.10
# GCC 13.2.0</th>
#       <th id="T_95deb_level0_col1" class="col_heading level0 col1" >Intel i7-1050H
# Ubuntu 23.10
# clang 17.0.2</th>
#       <th id="T_95deb_level0_col2" class="col_heading level0 col2" >Intel i7-1050H
# Windows 11 Home
# MSVC 19.39.33523</th>
#       <th id="T_95deb_level0_col3" class="col_heading level0 col3" >Intel i7-1050H
# Windows 11 Home
# GCC 14.1.0 (w64devkit)</th>
#       <th id="T_95deb_level0_col4" class="col_heading level0 col4" >AMD Ryzen 9 6900HX
# Ubuntu 23.10
# GCC 13.2.0</th>
#       <th id="T_95deb_level0_col5" class="col_heading level0 col5" >AMD Ryzen 9 6900HX
# Ubuntu 23.10
# clang 17.0.2</th>
#       <th id="T_95deb_level0_col6" class="col_heading level0 col6" >AMD Ryzen 9 6900HX
# Windows 11 Home
# MSVC 19.38.33135</th>
#       <th id="T_95deb_level0_col7" class="col_heading level0 col7" >AMD Ryzen 9 6900HX
# Windows 11 Home
# GCC 14.1.0 (w64devkit)</th>
#       <th id="T_95deb_level0_col8" class="col_heading level0 col8" >Apple M1
# macOS 14.4.1
# clang 15.0.0</th>
#       <th id="T_95deb_level0_col9" class="col_heading level0 col9" >Apple M1
# macOS 14.4.1
# GCC 13.2.0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95deb_level0_row0" class="row_heading level0 row0" >≥ 1% faster</th>
#       <td id="T_95deb_row0_col0" class="data row0 col0" >17.8%</td>
#       <td id="T_95deb_row0_col1" class="data row0 col1" >20.0%</td>
#       <td id="T_95deb_row0_col2" class="data row0 col2" >21.2%</td>
#       <td id="T_95deb_row0_col3" class="data row0 col3" >43.7%</td>
#       <td id="T_95deb_row0_col4" class="data row0 col4" >42.5%</td>
#       <td id="T_95deb_row0_col5" class="data row0 col5" >34.3%</td>
#       <td id="T_95deb_row0_col6" class="data row0 col6" >30.6%</td>
#       <td id="T_95deb_row0_col7" class="data row0 col7" >18.5%</td>
#       <td id="T_95deb_row0_col8" class="data row0 col8" >16.4%</td>
#       <td id="T_95deb_row0_col9" class="data row0 col9" >13.5%</td>
#     </tr>
#     <tr>
#       <th id="T_95deb_level0_row1" class="row_heading level0 row1" >≥ 2% faster</th>
#       <td id="T_95deb_row1_col0" class="data row1 col0" >13.3%</td>
#       <td id="T_95deb_row1_col1" class="data row1 col1" >14.9%</td>
#       <td id="T_95deb_row1_col2" class="data row1 col2" >11.9%</td>
#       <td id="T_95deb_row1_col3" class="data row1 col3" >32.0%</td>
#       <td id="T_95deb_row1_col4" class="data row1 col4" >35.4%</td>
#       <td id="T_95deb_row1_col5" class="data row1 col5" >22.8%</td>
#       <td id="T_95deb_row1_col6" class="data row1 col6" >20.4%</td>
#       <td id="T_95deb_row1_col7" class="data row1 col7" >10.7%</td>
#       <td id="T_95deb_row1_col8" class="data row1 col8" >8.8%</td>
#       <td id="T_95deb_row1_col9" class="data row1 col9" >6.8%</td>
#     </tr>
#     <tr>
#       <th id="T_95deb_level0_row2" class="row_heading level0 row2" >≥ 3% faster</th>
#       <td id="T_95deb_row2_col0" class="data row2 col0" >10.7%</td>
#       <td id="T_95deb_row2_col1" class="data row2 col1" >12.9%</td>
#       <td id="T_95deb_row2_col2" class="data row2 col2" >7.0%</td>
#       <td id="T_95deb_row2_col3" class="data row2 col3" >22.3%</td>
#       <td id="T_95deb_row2_col4" class="data row2 col4" >30.1%</td>
#       <td id="T_95deb_row2_col5" class="data row2 col5" >15.6%</td>
#       <td id="T_95deb_row2_col6" class="data row2 col6" >13.5%</td>
#       <td id="T_95deb_row2_col7" class="data row2 col7" >6.5%</td>
#       <td id="T_95deb_row2_col8" class="data row2 col8" >5.5%</td>
#       <td

# %%
# Show the slower cases
(table, make_pretty) = make_table_showing_performance_percentages('slower', 1, 10)
table.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_77839_row0_col0, #T_77839_row2_col6 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_77839_row0_col1 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_77839_row0_col2 {
#   background-color: #fd9d43;
#   color: #000000;
# }
# #T_77839_row0_col3 {
#   background-color: #feca66;
#   color: #000000;
# }
# #T_77839_row0_col4 {
#   background-color: #feba55;
#   color: #000000;
# }
# #T_77839_row0_col5 {
#   background-color: #febe59;
#   color: #000000;
# }
# #T_77839_row0_col6 {
#   background-color: #fead4a;
#   color: #000000;
# }
# #T_77839_row0_col7 {
#   background-color: #fea044;
#   color: #000000;
# }
# #T_77839_row0_col8, #T_77839_row4_col6 {
#   background-color: #ffeda0;
#   color: #000000;
# }
# #T_77839_row0_col9, #T_77839_row3_col2 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_77839_row1_col0 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_77839_row1_col1, #T_77839_row2_col3, #T_77839_row2_col5 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_77839_row1_col2 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_77839_row1_col3 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_77839_row1_col4 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_77839_row1_col5 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_77839_row1_col6 {
#   background-color: #fed470;
#   color: #000000;
# }
# #T_77839_row1_col7 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_77839_row1_col8, #T_77839_row7_col2 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_77839_row1_col9 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_77839_row2_col0, #T_77839_row3_col1, #T_77839_row4_col7, #T_77839_row6_col6 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_77839_row2_col1, #T_77839_row5_col6 {
#   background-color: #ffefa4;
#   color: #000000;
# }
# #T_77839_row2_col2 {
#   background-color: #fedb7b;
#   color: #000000;
# }
# #T_77839_row2_col4 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_77839_row2_col7 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_77839_row2_col8, #T_77839_row7_col7 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_77839_row2_col9, #T_77839_row8_col0 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_77839_row3_col0, #T_77839_row5_col1 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_77839_row3_col3, #T_77839_row4_col1, #T_77839_row7_col6 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_77839_row3_col4, #T_77839_row3_col5 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_77839_row3_col6 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_77839_row3_col7 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_77839_row3_col8 {
#   background-color: #fffcc5;
#   color: #000000;
# }
# #T_77839_row3_col9 {
#   background-color: #fff5b5;
#   color: #000000;
# }
# #T_77839_row4_col0, #T_77839_row5_col2, #T_77839_row7_col1, #T_77839_row8_col1 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_77839_row4_col2 {
#   background-color: #ffeda1;
#   color: #000000;
# }
# #T_77839_row4_col3, #T_77839_row4_col4, #T_77839_row4_col9 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_77839_row4_col5, #T_77839_row6_col2 {
#   background-color: #fff5b3;
#   color: #000000;
# }
# #T_77839_row4_col8, #T_77839_row5_col8, #T_77839_row8_col3, #T_77839_row8_col4, #T_77839_row8_col9 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_77839_row5_col0, #T_77839_row6_col0, #T_77839_row7_col0, #T_77839_row9_col1, #T_77839_row9_col6 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_77839_row5_col3, #T_77839_row5_col4, #T_77839_row9_col2 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_77839_row5_col5, #T_77839_row5_col9 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_77839_row5_col7, #T_77839_row9_col0 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_77839_row6_col1, #T_77839_row8_col6 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_77839_row6_col3, #T_77839_row9_col7 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_77839_row6_col4, #T_77839_row6_col5, #T_77839_row6_col9, #T_77839_row8_col7 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_77839_row6_col7, #T_77839_row8_col2 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_77839_row6_col8, #T_77839_row8_col5, #T_77839_row9_col3, #T_77839_row9_col4, #T_77839_row9_col9 {
#   background-color: #fffec9;
#   color: #000000;
# }
# #T_77839_row7_col3, #T_77839_row7_col4, #T_77839_row7_col5, #T_77839_row7_col9 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_77839_row7_col8, #T_77839_row8_col8, #T_77839_row9_col5, #T_77839_row9_col8 {
#   background-color: #fffecb;
#   color: #000000;
# }
# </style>
# <table id="T_77839">
#   <caption><h2>Percent of test cases that are slower with <code>noexcept</code> turned on</h2><h4>(out of 1950 test cases)</h4><br><br></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77839_level0_col0" class="col_heading level0 col0" >Intel i7-1050H
# Ubuntu 23.10
# GCC 13.2.0</th>
#       <th id="T_77839_level0_col1" class="col_heading level0 col1" >Intel i7-1050H
# Ubuntu 23.10
# clang 17.0.2</th>
#       <th id="T_77839_level0_col2" class="col_heading level0 col2" >Intel i7-1050H
# Windows 11 Home
# MSVC 19.39.33523</th>
#       <th id="T_77839_level0_col3" class="col_heading level0 col3" >Intel i7-1050H
# Windows 11 Home
# GCC 14.1.0 (w64devkit)</th>
#       <th id="T_77839_level0_col4" class="col_heading level0 col4" >AMD Ryzen 9 6900HX
# Ubuntu 23.10
# GCC 13.2.0</th>
#       <th id="T_77839_level0_col5" class="col_heading level0 col5" >AMD Ryzen 9 6900HX
# Ubuntu 23.10
# clang 17.0.2</th>
#       <th id="T_77839_level0_col6" class="col_heading level0 col6" >AMD Ryzen 9 6900HX
# Windows 11 Home
# MSVC 19.38.33135</th>
#       <th id="T_77839_level0_col7" class="col_heading level0 col7" >AMD Ryzen 9 6900HX
# Windows 11 Home
# GCC 14.1.0 (w64devkit)</th>
#       <th id="T_77839_level0_col8" class="col_heading level0 col8" >Apple M1
# macOS 14.4.1
# clang 15.0.0</th>
#       <th id="T_77839_level0_col9" class="col_heading level0 col9" >Apple M1
# macOS 14.4.1
# GCC 13.2.0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77839_level0_row0" class="row_heading level0 row0" >≥ 1% slower</th>
#       <td id="T_77839_row0_col0" class="data row0 col0" >19.3%</td>
#       <td id="T_77839_row0_col1" class="data row0 col1" >20.8%</td>
#       <td id="T_77839_row0_col2" class="data row0 col2" >44.7%</td>
#       <td id="T_77839_row0_col3" class="data row0 col3" >30.1%</td>
#       <td id="T_77839_row0_col4" class="data row0 col4" >35.0%</td>
#       <td id="T_77839_row0_col5" class="data row0 col5" >33.7%</td>
#       <td id="T_77839_row0_col6" class="data row0 col6" >39.3%</td>
#       <td id="T_77839_row0_col7" class="data row0 col7" >43.6%</td>
#       <td id="T_77839_row0_col8" class="data row0 col8" >12.8%</td>
#       <td id="T_77839_row0_col9" class="data row0 col9" >16.9%</td>
#     </tr>
#     <tr>
#       <th id="T_77839_level0_row1" class="row_heading level0 row1" >≥ 2% slower</th>
#       <td id="T_77839_row1_col0" class="data row1 col0" >14.3%</td>
#       <td id="T_77839_row1_col1" class="data row1 col1" >15.4%</td>
#       <td id="T_77839_row1_col2" class="data row1 col2" >33.3%</td>
#       <td id="T_77839_row1_col3" class="data row1 col3" >22.2%</td>
#       <td id="T_77839_row1_col4" class="data row1 col4" >26.1%</td>
#       <td id="T_77839_row1_col5" class="data row1 col5" >21.6%</td>
#       <td id="T_77839_row1_col6" class="data row1 col6" >26.9%</td>
#       <td id="T_77839_row1_col7" class="data row1 col7" >27.8%</td>
#       <td id="T_77839_row1_col8" class="data row1 col8" >6.0%</td>
#       <td id="T_77839_row1_col9" class="data row1 col9" >10.8%</td>
#     </tr>
#     <tr>
#       <th id="T_77839_level0_row2" class="row_heading level0 row2" >≥ 3% slower</th>
#       <td id="T_77839_row2_col0" class="data row2 col0" >10.5%</td>
#       <td id="T_77839_row2_col1" class="data row2 col1" >11.5%</td>
#       <td id="T_77839_row2_col2" class="data row2 col2" >23.6%</td>
#       <td id="T_77839_row2_col3" class="data row2 col3" >15.3%</td>
#       <td id="T_77839_row2_col4" class="data row2 col4" >17.5%</td>
#       <td id="T_77839_row2_

# %%
# Not a fan of doing this, but it extracts the scene Id's for us to display in the table
_scene_ids = []

def make_table_for_stat_measurement(function, table_title: str, cmap: str='RdBu', vmin=-0.1, vmax=0.1):
    '''This function will let you make a table that shows the summary for a "satistical measurement" function.

    For example, if you want to see the average performance increase/decrease of "feature-on" vs. "feature off", you would pass in
    `statistics.mean` to `function`.   If you wanted to see the Median, use `statistics.median`.  Note that this
    funtion returns a tuple of the pandas.DataFrame and an styling function to call on the data frame.
    '''
    
    global _scene_ids
    global num_test_cases_per_scene
    global num_test_cases

    data = {}
    for (config_index, config_name) in enumerate(configs):
        all_scenes = OrderedDict()
        suite = results[config_index]

        # Organize each scene to see how much percent faster it is
        for tc in suite.test_cases:
            sid = tc.scene_id
            p_faster = tc.percent_venture_faster_by()
            
            if sid in all_scenes:
                all_scenes[sid].append(p_faster)  # Add value
            else:
                all_scenes[sid] = [p_faster]      # New list

        scene_ids = []
        computed = []
        for (scene_id, measurements) in all_scenes.items():
            scene_ids.append(scene_id)
            computed.append(function(measurements))
            
            
        data[config_name] = computed
    
    def _make_pretty(styler):
        styler.format('{:.1%}')
        styler.set_table_styles([
            {'selector': '.row_heading', 'props': [('text-align', 'left')]}
        ])
        styler.background_gradient(axis=None, cmap=cmap, vmin=vmin, vmax=vmax)
        styler.set_caption(table_title)
        styler.relabel_index(_scene_ids, axis=0)
        return styler

    # Set globals (always will be the same)
    _scene_ids = scene_ids
    num_test_cases_per_scene = num_test_cases / len(_scene_ids)

    # Return data
    table = pd.DataFrame(data=data)
    return (table, _make_pretty)

# %%
(table, make_pretty) = make_table_for_stat_measurement(
    statistics.mean,
    f'<h2>Average of how much faster/slower was if <code>noexcept</code> was used</h2><h4>(Each scene being tested at least {int(num_test_cases_per_scene)} times)</h4><br><br>'
)
table.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_68897 .row_heading {
#   text-align: left;
# }
# #T_68897_row0_col0, #T_68897_row3_col2, #T_68897_row6_col8, #T_68897_row7_col0, #T_68897_row7_col3, #T_68897_row8_col3, #T_68897_row8_col5, #T_68897_row9_col0, #T_68897_row9_col5, #T_68897_row10_col2, #T_68897_row10_col3, #T_68897_row19_col3, #T_68897_row24_col8, #T_68897_row27_col9, #T_68897_row33_col2, #T_68897_row34_col3, #T_68897_row35_col7, #T_68897_row36_col9 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_68897_row0_col1, #T_68897_row1_col7, #T_68897_row23_col4, #T_68897_row34_col4 {
#   background-color: #fce2d2;
#   color: #000000;
# }
# #T_68897_row0_col2, #T_68897_row4_col1, #T_68897_row4_col5, #T_68897_row5_col5, #T_68897_row7_col7, #T_68897_row13_col6, #T_68897_row21_col1, #T_68897_row21_col5, #T_68897_row30_col4 {
#   background-color: #f9eee7;
#   color: #000000;
# }
# #T_68897_row0_col3, #T_68897_row2_col1 {
#   background-color: #fdd9c4;
#   color: #000000;
# }
# #T_68897_row0_col4 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# #T_68897_row0_col5, #T_68897_row0_col9, #T_68897_row2_col5, #T_68897_row6_col0, #T_68897_row10_col0, #T_68897_row10_col5, #T_68897_row16_col7, #T_68897_row17_col4, #T_68897_row24_col1, #T_68897_row28_col1, #T_68897_row29_col8, #T_68897_row30_col8, #T_68897_row35_col1, #T_68897_row36_col2 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_68897_row0_col6, #T_68897_row21_col3 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_68897_row0_col7, #T_68897_row9_col1, #T_68897_row9_col3, #T_68897_row13_col0, #T_68897_row20_col9, #T_68897_row23_col0, #T_68897_row25_col5, #T_68897_row27_col0, #T_68897_row30_col5, #T_68897_row31_col2 {
#   background-color: #f9efe9;
#   color: #000000;
# }
# #T_68897_row0_col8, #T_68897_row27_col6, #T_68897_row28_col3, #T_68897_row28_col5 {
#   background-color: #e6866a;
#   color: #f1f1f1;
# }
# #T_68897_row1_col0, #T_68897_row6_col7, #T_68897_row28_col0 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_68897_row1_col1, #T_68897_row6_col5, #T_68897_row15_col2, #T_68897_row25_col8 {
#   background-color: #fce0d0;
#   color: #000000;
# }
# #T_68897_row1_col2 {
#   background-color: #4f9bc7;
#   color: #f1f1f1;
# }
# #T_68897_row1_col3, #T_68897_row10_col8, #T_68897_row15_col3, #T_68897_row15_col8, #T_68897_row15_col9, #T_68897_row17_col1, #T_68897_row21_col8, #T_68897_row22_col0, #T_68897_row28_col9, #T_68897_row37_col0, #T_68897_row38_col8 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_68897_row1_col4, #T_68897_row10_col4, #T_68897_row11_col4 {
#   background-color: #327cb7;
#   color: #f1f1f1;
# }
# #T_68897_row1_col5, #T_68897_row4_col0, #T_68897_row4_col7, #T_68897_row6_col1, #T_68897_row32_col1 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_68897_row1_col6, #T_68897_row12_col1, #T_68897_row12_col8, #T_68897_row17_col7, #T_68897_row18_col4, #T_68897_row24_col5, #T_68897_row29_col2, #T_68897_row32_col0, #T_68897_row38_col0 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_68897_row1_col8, #T_68897_row15_col4, #T_68897_row22_col4, #T_68897_row22_col9, #T_68897_row24_col9, #T_68897_row32_col4, #T_68897_row35_col2 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_68897_row1_col9, #T_68897_row6_col2, #T_68897_row13_col1, #T_68897_row17_col5, #T_68897_row18_col9, #T_68897_row23_col5, #T_68897_row26_col3, #T_68897_row29_col9, #T_68897_row31_col3, #T_68897_row32_col8, #T_68897_row33_col8 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_68897_row2_col0, #T_68897_row3_col1, #T_68897_row19_col7, #T_68897_row26_col4, #T_68897_row27_col4, #T_68897_row28_col4, #T_68897_row31_col7 {
#   background-color: #fae8de;
#   color: #000000;
# }
# #T_68897_row2_col2, #T_68897_row2_col6, #T_68897_row4_col6, #T_68897_row13_col8, #T_68897_row15_col5, #T_68897_row19_col0, #T_68897_row25_col3, #T_68897_row26_col2, #T_68897_row32_col9 {
#   background-color: #f7f5f4;
#   color: #000000;
# }
# #T_68897_row2_col3, #T_68897_row3_col3, #T_68897_row22_col1, #T_68897_row27_col1 {
#   background-color: #e3edf3;
#   color: #000000;
# }
# #T_68897_row2_col4 {
#   background-color: #569fc9;
#   color: #f1f1f1;
# }
# #T_68897_row2_col7, #T_68897_row11_col0, #T_68897_row11_col1, #T_68897_row13_col2, #T_68897_row20_col6, #T_68897_row28_col2 {
#   background-color: #fae7dc;
#   color: #000000;
# }
# #T_68897_row2_col8, #T_68897_row22_col3, #T_68897_row37_col8 {
#   background-color: #e6eff4;
#   color: #000000;
# }
# #T_68897_row2_col9, #T_68897_row31_col0 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_68897_row3_col0, #T_68897_row3_col5, #T_68897_row3_col7, #T_68897_row5_col7, #T_68897_row8_col7 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_68897_row3_col4 {
#   background-color: #529dc8;
#   color: #f1f1f1;
# }
# #T_68897_row3_col6, #T_68897_row5_col1, #T_68897_row8_col1, #T_68897_row27_col8, #T_68897_row32_col7, #T_68897_row33_col0 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_68897_row3_col8, #T_68897_row6_col9, #T_68897_row16_col9, #T_68897_row21_col9, #T_68897_row28_col8 {
#   background-color: #f8f3f0;
#   color: #000000;
# }
# #T_68897_row3_col9, #T_68897_row4_col9, #T_68897_row5_col0, #T_68897_row5_col8, #T_68897_row10_col9, #T_68897_row20_col0, #T_68897_row20_col8, #T_68897_row25_col1, #T_68897_row31_col1, #T_68897_row35_col8, #T_68897_row37_col5 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_68897_row4_col2, #T_68897_row5_col2, #T_68897_row6_col6, #T_68897_row11_col2, #T_68897_row11_col8, #T_68897_row17_col9, #T_68897_row23_col6, #T_68897_row31_col6, #T_68897_row33_col1, #T_68897_row37_col9 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_68897_row4_col3, #T_68897_row7_col8, #T_68897_row9_col7, #T_68897_row11_col9, #T_68897_row13_col9, #T_68897_row14_col8, #T_68897_row17_col0, #T_68897_row18_col3, #T_68897_row20_col7, #T_68897_row22_col5, #T_68897_row26_col0, #T_68897_row36_col0 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_68897_row4_col4 {
#   background-color: #3c8abe;
#   color: #f1f1f1;
# }
# #T_68897_row4_col8, #T_68897_row8_col8, #T_68897_row9_col2, #T_68897_row9_col8, #T_68897_row12_col0, #T_68897_row17_col8, #T_68897_row18_col6, #T_68897_row20_col3, #T_68897_row24_col0, #T_68897_row31_col9, #T_68897_row33_col9, #T_68897_row34_col8, #T_68897_row34_col9 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_68897_row5_col3, #T_68897_row5_col9, #T_68897_row11_col3, #T_68897_row21_col7, #T_68897_row23_col3, #T_68897_row26_col1, #T_68897_row26_col6, #T_68897_row29_col1, #T_68897_row38_col3 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_68897_row5_col4 {
#   background-color: #3783bb;
#   color: #f1f1f1;
# }
# #T_68897_row5_col6, #T_68897_row7_col5, #T_68897_row34_col7, #T_68897_row35_col0 {
#   background-color: #faeae1;
#   color: #000000;
# }
# #T_68897_row6_col3, #T_68897_row8_col0, #T_68897_row10_col7, #T_68897_row13_col7, #T_68897_row16_col4, #T_68897_row18_col7, #T_68897_row20_col1, #T_68897_row23_col2, #T_68897_row23_col8, #T_68897_row25_col4, #T_68897_row25_col7, #T_68897_row29_col0, #T_68897_row30_col9, #T_68897_row33_col7, #T_68897_row36_col3 {
#   background-color: #f9f0eb;
#   color: #000000;
# }
# #T_68897_row6_col4 {
#   background-color: #4393c3;
#   color: #f1f1f1;
# }
# #T_68897_row7_col1 {
#   background-color: #f2a17f;
#   color: #000000;
# }
# #T_68897_row7_col2, #T_68897_row16_col5, #T_68897_row19_col5, #T_68897_row19_col9, #T_68897_row20_col5, #T_68897_row23_col7, #T_68897_row26_col9 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_68897_row7_col4 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_68897_row7_col6 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_68897_row7_col9, #T_68897_row27_col3, #T_68897_row29_col3, #T_68897_row32_col2 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_68897_row8_col2, #T_68897_row8_col9, #T_68897_row16_col1, #T_68897_row18_col5, #T_68897_row34_col0 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_68897_row8_col4 {
#   background-color: #4997c5;
#   color: #f1f1f1;
# }
# #T_68897_row8_col6, #T_68897_row20_col2 {
#   background-color: #fddcc9;
#   color: #000000;
# }
# #T_68897_row9_col4 {
#   background-color: #2e77b5;
#   color: #f1f1f1;
# }
# #T_68897_row9_col6 {

# %%
(table, make_pretty) = make_table_for_stat_measurement(
    statistics.median,
    f'<h2>Median of how much faster/slower was if <code>noexcept</code> was used</h2><h4>(Each scene being tested at least {int(num_test_cases_per_scene)} times)</h4><br><br>'
)
table.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_cad0d .row_heading {
#   text-align: left;
# }
# #T_cad0d_row0_col0, #T_cad0d_row2_col0, #T_cad0d_row2_col5, #T_cad0d_row2_col6, #T_cad0d_row3_col9, #T_cad0d_row4_col0, #T_cad0d_row4_col3, #T_cad0d_row6_col0, #T_cad0d_row6_col3, #T_cad0d_row8_col0, #T_cad0d_row8_col5, #T_cad0d_row9_col3, #T_cad0d_row10_col0, #T_cad0d_row10_col8, #T_cad0d_row11_col2, #T_cad0d_row13_col8, #T_cad0d_row13_col9, #T_cad0d_row15_col1, #T_cad0d_row16_col0, #T_cad0d_row16_col2, #T_cad0d_row17_col0, #T_cad0d_row17_col1, #T_cad0d_row17_col4, #T_cad0d_row18_col0, #T_cad0d_row18_col3, #T_cad0d_row19_col1, #T_cad0d_row20_col0, #T_cad0d_row20_col1, #T_cad0d_row22_col5, #T_cad0d_row23_col0, #T_cad0d_row23_col8, #T_cad0d_row24_col0, #T_cad0d_row25_col1, #T_cad0d_row25_col8, #T_cad0d_row25_col9, #T_cad0d_row26_col1, #T_cad0d_row26_col8, #T_cad0d_row28_col0, #T_cad0d_row28_col1, #T_cad0d_row31_col0, #T_cad0d_row32_col9, #T_cad0d_row36_col0, #T_cad0d_row37_col9, #T_cad0d_row38_col9 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_cad0d_row0_col1, #T_cad0d_row0_col2, #T_cad0d_row3_col1, #T_cad0d_row11_col0, #T_cad0d_row13_col7, #T_cad0d_row15_col4, #T_cad0d_row17_col2, #T_cad0d_row18_col1, #T_cad0d_row18_col7, #T_cad0d_row19_col0, #T_cad0d_row19_col6, #T_cad0d_row20_col6, #T_cad0d_row27_col3, #T_cad0d_row30_col8, #T_cad0d_row32_col1, #T_cad0d_row33_col3 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_cad0d_row0_col3, #T_cad0d_row11_col6, #T_cad0d_row13_col4, #T_cad0d_row25_col2, #T_cad0d_row25_col6, #T_cad0d_row30_col7, #T_cad0d_row37_col4, #T_cad0d_row38_col2 {
#   background-color: #fddcc9;
#   color: #000000;
# }
# #T_cad0d_row0_col4, #T_cad0d_row3_col4 {
#   background-color: #4393c3;
#   color: #f1f1f1;
# }
# #T_cad0d_row0_col5, #T_cad0d_row1_col8, #T_cad0d_row3_col8, #T_cad0d_row4_col1, #T_cad0d_row7_col8, #T_cad0d_row8_col8, #T_cad0d_row13_col1, #T_cad0d_row15_col6, #T_cad0d_row16_col1, #T_cad0d_row16_col4, #T_cad0d_row23_col1, #T_cad0d_row23_col4, #T_cad0d_row24_col4, #T_cad0d_row30_col0, #T_cad0d_row30_col4, #T_cad0d_row36_col2 {
#   background-color: #f8f3f0;
#   color: #000000;
# }
# #T_cad0d_row0_col6, #T_cad0d_row3_col2, #T_cad0d_row8_col9, #T_cad0d_row9_col5, #T_cad0d_row13_col0, #T_cad0d_row15_col3, #T_cad0d_row16_col3, #T_cad0d_row18_col6, #T_cad0d_row20_col3, #T_cad0d_row27_col9, #T_cad0d_row30_col1, #T_cad0d_row33_col9, #T_cad0d_row35_col7, #T_cad0d_row38_col3 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_cad0d_row0_col7, #T_cad0d_row1_col1, #T_cad0d_row2_col1, #T_cad0d_row5_col6, #T_cad0d_row6_col1, #T_cad0d_row21_col9, #T_cad0d_row30_col9 {
#   background-color: #f9f0eb;
#   color: #000000;
# }
# #T_cad0d_row0_col8, #T_cad0d_row8_col3, #T_cad0d_row23_col7, #T_cad0d_row27_col0, #T_cad0d_row28_col3, #T_cad0d_row33_col2, #T_cad0d_row34_col9, #T_cad0d_row35_col3, #T_cad0d_row35_col8 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_cad0d_row0_col9, #T_cad0d_row1_col0, #T_cad0d_row4_col5, #T_cad0d_row4_col8, #T_cad0d_row5_col1, #T_cad0d_row8_col1, #T_cad0d_row9_col9, #T_cad0d_row10_col1, #T_cad0d_row11_col1, #T_cad0d_row15_col5, #T_cad0d_row23_col6, #T_cad0d_row23_col9, #T_cad0d_row25_col4, #T_cad0d_row25_col5, #T_cad0d_row29_col8, #T_cad0d_row31_col1, #T_cad0d_row31_col2, #T_cad0d_row33_col0, #T_cad0d_row33_col1 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_cad0d_row1_col2 {
#   background-color: #aed3e6;
#   color: #000000;
# }
# #T_cad0d_row1_col3, #T_cad0d_row2_col8, #T_cad0d_row7_col3, #T_cad0d_row7_col9, #T_cad0d_row8_col2, #T_cad0d_row14_col8, #T_cad0d_row18_col8, #T_cad0d_row19_col5, #T_cad0d_row29_col1, #T_cad0d_row32_col8, #T_cad0d_row33_col8, #T_cad0d_row35_col1, #T_cad0d_row37_col5, #T_cad0d_row38_col8 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_cad0d_row1_col4 {
#   background-color: #2a71b2;
#   color: #f1f1f1;
# }
# #T_cad0d_row1_col5, #T_cad0d_row6_col5 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_cad0d_row1_col6, #T_cad0d_row12_col6, #T_cad0d_row13_col6, #T_cad0d_row19_col7, #T_cad0d_row30_col5 {
#   background-color: #f9ede5;
#   color: #000000;
# }
# #T_cad0d_row1_col7, #T_cad0d_row4_col7, #T_cad0d_row13_col2, #T_cad0d_row26_col5, #T_cad0d_row28_col7 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_cad0d_row1_col9, #T_cad0d_row2_col2, #T_cad0d_row6_col2, #T_cad0d_row10_col2, #T_cad0d_row12_col1, #T_cad0d_row15_col9, #T_cad0d_row17_col8, #T_cad0d_row17_col9, #T_cad0d_row19_col9, #T_cad0d_row21_col8, #T_cad0d_row23_col3, #T_cad0d_row28_col9, #T_cad0d_row32_col0, #T_cad0d_row34_col8, #T_cad0d_row36_col9 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_cad0d_row2_col3, #T_cad0d_row14_col0, #T_cad0d_row22_col7 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_cad0d_row2_col4, #T_cad0d_row30_col6 {
#   background-color: #6bacd1;
#   color: #f1f1f1;
# }
# #T_cad0d_row2_col7, #T_cad0d_row3_col5, #T_cad0d_row17_col7 {
#   background-color: #fae8de;
#   color: #000000;
# }
# #T_cad0d_row2_col9, #T_cad0d_row3_col0, #T_cad0d_row4_col2, #T_cad0d_row4_col6, #T_cad0d_row4_col9, #T_cad0d_row5_col0, #T_cad0d_row5_col2, #T_cad0d_row6_col6, #T_cad0d_row7_col0, #T_cad0d_row7_col5, #T_cad0d_row9_col0, #T_cad0d_row9_col2, #T_cad0d_row9_col8, #T_cad0d_row10_col9, #T_cad0d_row11_col8, #T_cad0d_row11_col9, #T_cad0d_row15_col8, #T_cad0d_row16_col8, #T_cad0d_row18_col9, #T_cad0d_row22_col1, #T_cad0d_row22_col8, #T_cad0d_row24_col8, #T_cad0d_row26_col2, #T_cad0d_row28_col6, #T_cad0d_row29_col0, #T_cad0d_row31_col9, #T_cad0d_row34_col1, #T_cad0d_row35_col0, #T_cad0d_row36_col3, #T_cad0d_row36_col8, #T_cad0d_row37_col0 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_cad0d_row3_col3, #T_cad0d_row34_col6, #T_cad0d_row36_col5, #T_cad0d_row37_col1 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_cad0d_row3_col6, #T_cad0d_row8_col7, #T_cad0d_row10_col5, #T_cad0d_row25_col3, #T_cad0d_row31_col7 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_cad0d_row3_col7, #T_cad0d_row19_col4, #T_cad0d_row26_col7, #T_cad0d_row27_col7, #T_cad0d_row34_col4 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_cad0d_row4_col4 {
#   background-color: #3885bc;
#   color: #f1f1f1;
# }
# #T_cad0d_row5_col3, #T_cad0d_row12_col0, #T_cad0d_row12_col4, #T_cad0d_row12_col5, #T_cad0d_row14_col5, #T_cad0d_row15_col0, #T_cad0d_row26_col3, #T_cad0d_row26_col9 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_cad0d_row5_col4, #T_cad0d_row7_col4 {
#   background-color: #3783bb;
#   color: #f1f1f1;
# }
# #T_cad0d_row5_col5, #T_cad0d_row6_col9, #T_cad0d_row9_col7, #T_cad0d_row22_col4, #T_cad0d_row25_col0, #T_cad0d_row27_col8, #T_cad0d_row33_col7, #T_cad0d_row36_col1 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_cad0d_row5_col7, #T_cad0d_row6_col7, #T_cad0d_row29_col7, #T_cad0d_row35_col2, #T_cad0d_row36_col6 {
#   background-color: #fae7dc;
#   color: #000000;
# }
# #T_cad0d_row5_col8, #T_cad0d_row9_col1, #T_cad0d_row12_col8, #T_cad0d_row16_col7, #T_cad0d_row16_col9, #T_cad0d_row20_col4, #T_cad0d_row20_col7, #T_cad0d_row20_col8, #T_cad0d_row20_col9, #T_cad0d_row21_col0, #T_cad0d_row21_col1, #T_cad0d_row21_col4, #T_cad0d_row22_col0, #T_cad0d_row22_col9, #T_cad0d_row23_col2, #T_cad0d_row24_col1, #T_cad0d_row24_col9, #T_cad0d_row27_col1, #T_cad0d_row27_col6, #T_cad0d_row28_col8, #T_cad0d_row32_col4, #T_cad0d_row34_col0, #T_cad0d_row35_col9, #T_cad0d_row37_col3 {
#   background-color: #f7f5f4;
#   color: #000000;
# }
# #T_cad0d_row5_col9, #T_cad0d_row16_col5, #T_cad0d_row18_col5, #T_cad0d_row20_col5, #T_cad0d_row31_col8, #T_cad0d_row32_col2 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_cad0d_row6_col4 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# #T_cad0d_row6_col8, #T_cad0d_row17_col5, #T_cad0d_row19_col3, #T_cad0d_row21_col3, #T_cad0d_row25_col7, #T_cad0d_row29_col9, #T_cad0d_row37_col8 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_cad0d_row7_col1, #T_cad0d_row7_col7, #T_cad0d_row21_col5, #T_cad0d_row24_col5, #T_cad0d_row28_col4, #T_cad0d_row32_col7 {
#   background-color: #faeae1;
#   color: #000000;
# }
# #T_cad0d_row7_col2, #T_cad0d_row23_col5, #T_cad0d_row31_col3, #T_cad0d_row34_col3, #T_cad0d_row

# %%
(table, make_pretty) = make_table_for_stat_measurement(
    statistics.variance,
    f'<h2>Variance of data measurements for <code>noexcept</code> being on.</h2><h4>(Each scene being tested at least {int(num_test_cases_per_scene)} times), lower is better</h4><br><br>',
    cmap='Reds',
    vmin=0.01,
    vmax=0.1
)
table.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_a92a8 .row_heading {
#   text-align: left;
# }
# #T_a92a8_row0_col0, #T_a92a8_row0_col1, #T_a92a8_row0_col2, #T_a92a8_row0_col3, #T_a92a8_row0_col4, #T_a92a8_row0_col5, #T_a92a8_row0_col6, #T_a92a8_row0_col7, #T_a92a8_row0_col9, #T_a92a8_row1_col0, #T_a92a8_row1_col1, #T_a92a8_row1_col2, #T_a92a8_row1_col3, #T_a92a8_row1_col4, #T_a92a8_row1_col5, #T_a92a8_row1_col6, #T_a92a8_row1_col7, #T_a92a8_row1_col8, #T_a92a8_row1_col9, #T_a92a8_row2_col0, #T_a92a8_row2_col1, #T_a92a8_row2_col2, #T_a92a8_row2_col3, #T_a92a8_row2_col4, #T_a92a8_row2_col5, #T_a92a8_row2_col6, #T_a92a8_row2_col7, #T_a92a8_row2_col8, #T_a92a8_row3_col0, #T_a92a8_row3_col1, #T_a92a8_row3_col2, #T_a92a8_row3_col3, #T_a92a8_row3_col4, #T_a92a8_row3_col5, #T_a92a8_row3_col6, #T_a92a8_row3_col7, #T_a92a8_row3_col8, #T_a92a8_row3_col9, #T_a92a8_row4_col0, #T_a92a8_row4_col1, #T_a92a8_row4_col2, #T_a92a8_row4_col3, #T_a92a8_row4_col4, #T_a92a8_row4_col5, #T_a92a8_row4_col6, #T_a92a8_row4_col7, #T_a92a8_row4_col8, #T_a92a8_row4_col9, #T_a92a8_row5_col0, #T_a92a8_row5_col1, #T_a92a8_row5_col2, #T_a92a8_row5_col3, #T_a92a8_row5_col4, #T_a92a8_row5_col5, #T_a92a8_row5_col6, #T_a92a8_row5_col7, #T_a92a8_row5_col8, #T_a92a8_row5_col9, #T_a92a8_row6_col0, #T_a92a8_row6_col1, #T_a92a8_row6_col2, #T_a92a8_row6_col3, #T_a92a8_row6_col4, #T_a92a8_row6_col5, #T_a92a8_row6_col6, #T_a92a8_row6_col7, #T_a92a8_row6_col8, #T_a92a8_row6_col9, #T_a92a8_row7_col0, #T_a92a8_row7_col1, #T_a92a8_row7_col2, #T_a92a8_row7_col3, #T_a92a8_row7_col4, #T_a92a8_row7_col5, #T_a92a8_row7_col6, #T_a92a8_row7_col7, #T_a92a8_row7_col8, #T_a92a8_row7_col9, #T_a92a8_row8_col0, #T_a92a8_row8_col1, #T_a92a8_row8_col2, #T_a92a8_row8_col3, #T_a92a8_row8_col4, #T_a92a8_row8_col5, #T_a92a8_row8_col6, #T_a92a8_row8_col7, #T_a92a8_row8_col8, #T_a92a8_row8_col9, #T_a92a8_row9_col0, #T_a92a8_row9_col1, #T_a92a8_row9_col2, #T_a92a8_row9_col3, #T_a92a8_row9_col4, #T_a92a8_row9_col5, #T_a92a8_row9_col6, #T_a92a8_row9_col7, #T_a92a8_row9_col8, #T_a92a8_row9_col9, #T_a92a8_row10_col0, #T_a92a8_row10_col1, #T_a92a8_row10_col2, #T_a92a8_row10_col3, #T_a92a8_row10_col4, #T_a92a8_row10_col5, #T_a92a8_row10_col6, #T_a92a8_row10_col7, #T_a92a8_row10_col8, #T_a92a8_row10_col9, #T_a92a8_row11_col0, #T_a92a8_row11_col1, #T_a92a8_row11_col2, #T_a92a8_row11_col3, #T_a92a8_row11_col4, #T_a92a8_row11_col5, #T_a92a8_row11_col7, #T_a92a8_row11_col8, #T_a92a8_row11_col9, #T_a92a8_row12_col0, #T_a92a8_row12_col1, #T_a92a8_row12_col2, #T_a92a8_row12_col3, #T_a92a8_row12_col4, #T_a92a8_row12_col5, #T_a92a8_row12_col7, #T_a92a8_row12_col8, #T_a92a8_row12_col9, #T_a92a8_row13_col0, #T_a92a8_row13_col1, #T_a92a8_row13_col2, #T_a92a8_row13_col3, #T_a92a8_row13_col4, #T_a92a8_row13_col5, #T_a92a8_row13_col6, #T_a92a8_row13_col7, #T_a92a8_row13_col8, #T_a92a8_row13_col9, #T_a92a8_row14_col0, #T_a92a8_row14_col1, #T_a92a8_row14_col2, #T_a92a8_row14_col3, #T_a92a8_row14_col4, #T_a92a8_row14_col5, #T_a92a8_row14_col7, #T_a92a8_row14_col8, #T_a92a8_row14_col9, #T_a92a8_row15_col0, #T_a92a8_row15_col1, #T_a92a8_row15_col2, #T_a92a8_row15_col3, #T_a92a8_row15_col4, #T_a92a8_row15_col5, #T_a92a8_row15_col6, #T_a92a8_row15_col7, #T_a92a8_row15_col8, #T_a92a8_row15_col9, #T_a92a8_row16_col0, #T_a92a8_row16_col1, #T_a92a8_row16_col2, #T_a92a8_row16_col3, #T_a92a8_row16_col4, #T_a92a8_row16_col5, #T_a92a8_row16_col6, #T_a92a8_row16_col7, #T_a92a8_row16_col8, #T_a92a8_row16_col9, #T_a92a8_row17_col0, #T_a92a8_row17_col1, #T_a92a8_row17_col2, #T_a92a8_row17_col3, #T_a92a8_row17_col4, #T_a92a8_row17_col5, #T_a92a8_row17_col6, #T_a92a8_row17_col7, #T_a92a8_row17_col8, #T_a92a8_row17_col9, #T_a92a8_row18_col0, #T_a92a8_row18_col1, #T_a92a8_row18_col2, #T_a92a8_row18_col3, #T_a92a8_row18_col4, #T_a92a8_row18_col5, #T_a92a8_row18_col6, #T_a92a8_row18_col7, #T_a92a8_row18_col8, #T_a92a8_row18_col9, #T_a92a8_row19_col0, #T_a92a8_row19_col1, #T_a92a8_row19_col2, #T_a92a8_row19_col3, #T_a92a8_row19_col4, #T_a92a8_row19_col5, #T_a92a8_row19_col6, #T_a92a8_row19_col7, #T_a92a8_row19_col8, #T_a92a8_row19_col9, #T_ ...
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_a92a8_row0_col8 {
#   background-color:
